# %% [markdown]
# <a href="https://colab.research.google.com/github/kuchsk/skillfactory/blob/main/!Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
.count()	Количество непустых значений
.mean()	Среднее значение
.mode()  режим всех элементов данных
.min()	Минимальное значение
.max()	Максимальное значение
.deviance()	Дисперсия
.std()	Стандартное отклонение
.sum()	Сумма
.prod()  произведение значений данных
.cumsum()  кумулятивную сумму значений данных
.cumprod()  совокупное произведение значений данных
.abs()  абсолютное значение
.quantile(x)	Квантиль уровня x
.nunique()	Число уникальных значений
.notna() - не пустые
.unique()
.value_counts(normalize=True)
.dropna(inplace = True)
.describe() отображает статистическую сводку всех записей за один снимок, т.е. (сумма, количество, мин, среднее и т. Д.)
h3 = pd.concat([h1, h2], axis = 0)
.replace('tbd', np.NaN).astype('float64')


df[~df['Name'].str.contains('some')]
df.drop(['name', 'name2'], axis = 1, inplace = True)
df['one'] = df['secondone'].round(1)
df.rename(columns = {'val':'value'}, inplace = True)

df.sort_values(['val'], ascending = False)
df['val']['mean'].sort_values(ascending = False)

df[df['year'] == 2019].nlargest(5, 'val')
df[(df['location'].isin(['Ru','US','Fra'])) & (df['year'] == 2019)].nlargest(5,'val')

data['Year_of_Release'] = data.Year_of_Release.astype('Int64')

df_one = df.groupby(['cause', 'sex']).agg({'year': ['count'],
                                  'val': ['mean', 'median']})

tt.xs('Transport injuries', level = 'cause')['val'].loc['Male', 'mean'] #Вырвать пересечение
d.pivot_table(values='val', index=['location', 'year'], columns='cause', aggfunc='mean', fill_value=None, margins=True, dropna=True, margins_name='All', observed=False, sort=True)

display(data.iloc[:, 1:7].sort_values(['Price'], ascending = False))

df.rename(columns = {'val':'val2' , 'val3':'val4'}, inplace = True)
pd.merge(df1, df2 on = ['location', 'sex', 'age'], how = 'inner')
op = pd.merge(o, p, left_on= 'ID товара', right_on = 'Product_ID', how = 'left')


weekdays = pd.to_datetime(df["Date"]).dt.dayofweek
-------------------------------------------------------------------------------------------------------------------
время   dt.
years_sold = melb_df['Date'].dt.year

date — дата;
year, month, day — год, месяц, день;
time — время;
hour, minute, second — час, минута, секунда;
dayofweek — номер дня недели, от 0 до 6, где 0 — понедельник, 6 — воскресенье;
day_name — название дня недели;
dayofyear — порядковый день года;
quarter — квартал (интервал в три месяца).

delta_days = melb_df['Date'] - pd.to_datetime('2016-01-01') #301 days...
.reset_index().iloc[0] # вернет индекс серии - если нужно получить имя индекса, а не значение по индексу
s.reset_index()['Date'].unique().tolist()
-------------------------------------------------------------------------------------------------------------------


m['Big'] = m.Landsize.apply(lambda x: 'Big' if x > 200 else False)

-------------------------------------------------------------------------------------------------------------------
d0 = pd.read_csv('c:/1/log.0.txt', sep = r'( |(?<=^\d{2})|:|,|>)', error_bad_lines=False)
d00 = pd.read_csv('c:/1/log.0.txt', sep = r'( |(?<=^\d{2})|,|>)', error_bad_lines=False)
# dtip = pd.DataFrame({'date': (d0.iloc[:,0]), 'time' : (d00.iloc[:,2]), 'ip': (d0.iloc[:,60])})
dtip = pd.DataFrame({'date': (pd.to_datetime(d0.iloc[:,0], format= '%b/%d/%Y')), 'time' : (d00.iloc[:,2]), 'ip': (d0.iloc[:,60])})
dtip.to_csv('c:/1/dtip0.csv', sep = ';', index=False)
print('Самые злобные атакеры')
print(pd.DataFrame(d0.iloc[:,60]).value_counts())

-------------------------------------------------------------------------------------------------------------------
display(ndf[(ndf['ip'].isin(['203.86.235.224']))])
#.str.contains лучше

df.groupby('val').agg('mean')


data['FirstName'] = data['EmployeeName'].apply(lambda x : x.split()[0])

df['name'].value_counts()[:5].sort_values(ascending=False)
df['name'].apply(lambda name: name.split()[-1]).value_counts()[:5] - top 5 most common lastname
display(m.SellerG.value_counts().nlargest(49).index)




print(list(re.findall('\d\d\d\d', i) for i in c.title if len(i) > 0))

c[c.title.str.contains('\(2018')].groupby('genres')['rating'].agg(['mean', 'count']).nlargest(1,'count')

# %%
# Format Code	Description	Examples
# %a	Weekday, abbreviated	Mon, Tues, Sat
# %A	Weekday, full name	Monday, Tuesday, Saturday
# %w	Weekday, decimal. 0=Sunday	1, 2, 6
# %d	Day of month, zero-padded	01, 02, 21
# %b	Month, abbreviated	Jan, Feb, Sep
# %B	Month, full name	January, February, September
# %m	Month number, zero-padded	01, 02, 09
# %y	Year, without century, zero-padded	02, 95, 99
# %Y	Year, with century	1990, 2020
# %H	Hour (24 hour), zero padded	01, 22
# %I	Hour (12 hour) zero padded	01, 12
# %p	AM or PM	AM, PM
# %M	Minute, zero-padded	01, 02, 43
# %S	Second, zero padded	01, 32, 59
# %f	Microsecond, zero-padded	000001, 000342, 999999
# %z	UTC offset ±HHMM[SS[.ffffff]]	+0000, -1030, -3423.234
# %Z	Time zone name	ITC, EST, CST
# %j	Day of year, zero-padded	001, 365, 023
# %U	Week # of year, zero-padded. Sunday first day of week	00, 01, 51
# %W	Week # of year, zero-padded. Monday first day of week	00, 02, 51
# %c	Appropriate date and time	Monday Feb 01 21:30:00 1990
# %x	Appropriate Date	02/01/90
# %X	Appropriate Time	21:22:00
%%	Literal '%' – Use this when you have a % sign in your format.	%

# %%
# Задание 2.4 (Внешний источник) 2.2.4

import pandas as pd

def create_medications(names, counts):
  medications = pd.Series(data = counts, index = names, name = "medications")
  # display(medications)
  return medications

"""    Напишите функцию create_mediactions(names, counts), которая  создает Series medications,
    индексами которой являются названия лекарств names, а значениями - их количество в поставке counts    """

def get_percent(medications, name):
  return ((medications[name])*100/sum(medications))

"""    А также напишите функцию get_percent(medications, name), которая возвращает долю количества товара
    с именем name от общего количества товаров в поставке в процентах. """

if __name__ == '__main__':
    names=['chlorhexidine', 'cyntomycin', 'afobazol']
    counts=[15, 18, 7]
    medications = create_medications(names, counts)
    print(get_percent(medications, "chlorhexidine")) #37.5
# Out:
# chlorhexidine    15
# cyntomycin       18
# afobazol          7
# Name: medications, dtype: int64
# 37.5

# %%
import pandas as pd
my_series = pd.Series(data=[5, 6, 7, 8, 9, 10], index=['a', 'b', 'c', 'd', 'e', 'f'])
display(my_series[['b', 'c', 'e']])
my_series.iloc[[1, 2, 4]]
# Out:
# b    6
# c    7
# e    9
# dtype: int64
# b    6
# c    7
# e    9
# dtype: int64

# %%
pd.Series(data=["Апельсин", "Киви", "Мандарин", "Яблоко"], index = ["а", "к", "м", "я"], name = "fruits")
# Out:
# а    Апельсин
# к        Киви
# м    Мандарин
# я      Яблоко
# Name: fruits, dtype: object

# %%
pd.Series({'а': "Апельсин", 'к': 'Киви', 'м': 'Мандарин', 'я': 'Яблоко'}, name='fruits')
# Out:
# а    Апельсин
# к        Киви
# м    Мандарин
# я      Яблоко
# Name: fruits, dtype: object

# %%
names=['chlorhexidine', 'cyntomycin', 'afobazol']
counts=[15, 18, 7]

def create_mediactions(names, counts):
  mediactions = pd.Series(data = names, index = counts, name = 'medications')
  return mediactions

create_mediactions(names, counts)
# Out:
# 15    chlorhexidine
# 18       cyntomycin
# 7          afobazol
# Name: medications, dtype: object

# %%
names=['chlorhexidine', 'cyntomycin', 'afobazol']
counts=[15, 18, 7]

def create_mediactions(names, counts):
  mediactions = pd.Series(data = names, index = counts, name = 'medications')
  return mediactions

create_mediactions(names, counts)
# Out:
# 15    chlorhexidine
# 18       cyntomycin
# 7          afobazol
# Name: medications, dtype: object

# %%
countries_df = pd.DataFrame(
    data = [
        ['Англия', 56.29, 133396],
        ['Канада', 38.05, 9984670],
        ['США', 322.28, 9826630],
        ['Россия', 146.24, 17125191],
        ['Украина', 45.5, 603628],
        ['Беларусь', 9.5, 207600],
        ['Казахстан', 17.04, 2724902]
    ],
    columns= ['country', 'population', 'square'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
)
display(countries_df)
display(countries_df.loc[['UA', 'BY', 'KZ'],['population', 'square']])
display(countries_df.iloc[0:1, 0:1])                                                    #!!!!!!!!!!!!!!!!!!!!!!!!!!!
display(countries_df.loc[['UA'], ['population']])
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902
#     population   square
# UA       45.50   603628
# BY        9.50   207600
# KZ       17.04  2724902
#    country
# UK  Англия
#     population
# UA        45.5

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})
countries_df.index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']       #отдельно задаем index если не нужны цифры от 0
display(countries_df) #vs                                                                     !!!display vs print
print(countries_df)

# %%
#axis 0 / 1 столбцы строки
display(countries_df.mean(axis = 1))
print(countries_df.mean(axis = 0))
type(countries_df.population)

# %%
# обращаться можно через . и через [''] Если есть пробел в имени
print(countries_df.population)

# %%
countries_df.loc['UK','square']
# Out:
# 133396

# %%
countries_df.loc['RU',['population', 'square']]

# %%
countries_df.loc[['UA','BY', 'KZ'],['population', 'square']]
# Out:
#     population   square
# UA       45.50   603628
# BY        9.50   207600
# KZ       17.04  2724902

# %%
countries_df.iloc[4:8,1:3]
# Out:
#     population   square
# UA       45.50   603628
# BY        9.50   207600
# KZ       17.04  2724902

# %%
pd.DataFrame([[0,1], [1, 0]], columns=['А', 'B'])
# Out:
#    0  1
# 0  0  1
# 1  1  0

# %%
pd.DataFrame({'А': [0, 1], 'B': [1, 0]})
# Out:
#    А  B
# 0  0  1
# 1  1  0

# %%
# Задание 3.5 (Внешний источник) 2.3.5
'''Создайте функцию create_companyDF(incomes, expenses, years), которая  возвращает DataFrame,
составленный из входных данных со столбцами Incomes и Expenses и индексами, соответствующими
годам рассматриваемого периода. Пример такого DataFrame представлен ниже.

Incomes	Expenses
2018	478	156
2019	512	130
2020	196	270
Также напишите функцию get_profit(df, year), которая возвращает разницу между доходом и
расходом, записанными в таблице df, за год year. Учтите, что если информация за
запрашиваемый год не указана в вашей таблице, вам необходимо вернуть None.
'''
import pandas as pd
def create_companyDF(incomes, expenses, years):
  df = pd.DataFrame({'expenses':[i for i in expenses],'incomes':[b for b in incomes]}, index = (years))
  # df1 = pd.DataFrame(expenses)
  # display(df1)
  return df

def get_profit(df, year):
  if year in df.index:
    # print(df.index[((list(df.index)).index(year))])
    return df.incomes[year] - df.expenses[year]
  else:
    return None


if __name__ == '__main__':
    expenses = [156, 130, 270]
    incomes = [478, 512, 196]
    years = [2018, 2019, 2020]

scienceyou = create_companyDF(incomes, expenses, years)
print(get_profit(scienceyou, 2020)) #-74
# Out:
# -74

# %%
expenses = [156, 130, 270]
incomes = [478, 512, 196]
years = [2018, 2019, 2020]
k = pd.DataFrame({'expenses':[i for i in expenses],'incomes':[b for b in incomes]}, index = (years))

display(k)

display(list(d for d in k.index))

print(list(d for d in k.index if d == 2020))
print(k.iloc[0:1])
print(k.index[1])
# Out:
#       expenses  incomes
# 2018       156      478
# 2019       130      512
# 2020       270      196
# [2018, 2019, 2020]
# [2020]
#       expenses  incomes
# 2018       156      478
# 2019

# %%
pd.DataFrame({'А': [0, 1], 'B': [1, 0]})
# Out:
#    А  B
# 0  0  1
# 1  1  0

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv')
display(data)
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
rate = 0.12
income = data['Price'].sum()* rate
print('Total income or real estate agents:', round(income, 2))
# Out:
# Total income or real estate agents: 2332680778.92

# %%
data['Distance'].std()
# Out:
# 6.00904973121445

# %%
((data['BuildingArea'].median()/data['BuildingArea'].mean())*100-100).round(0)
# Out:
# -17.0

# %%
data['BuildingArea'].mean()
# Out:
# 151.22021949239888

# %%
dd3=pd.DataFrame([1, 2, 4, 2, 3, 2, 1, 5, 6])
dd3.mode()
# Out:
#    0
# 0  2

# %%
data['Bedroom2'].value_counts()
# Out:
# 3.0     6463
# 2.0     4124
# 4.0     2864
# 1.0      763
# 5.0      604
# 6.0       71
# 0.0       16
# 7.0       12
# 8.0        5
# 9.0        3
# 20.0       1
# 10.0       1
# Name: Bedroom2, dtype: int64

# %%
BuildingArea_median = data['BuildingArea'].median()
BuildingArea_mean =  data['BuildingArea'].mean()
print((abs(BuildingArea_median - BuildingArea_mean)/BuildingArea_mean*100).round(0))
# Out:
# 17.0

# %%
print(abs(data['BuildingArea'].median()-data['BuildingArea'].mean())/data['BuildingArea'].mean())
# Out:
# 0.16677809076759462

# %%
mask = data['Price'] > 2000000
# display(data[data.Price > 2000000])

data[(data['Rooms'] == 3) & (data.Price < 300000)].shape[0]
# Out:
# 5

# %%
data[data['Type']=='t']['Rooms'].max()
# Out:
# 5

# %%
data[(data.Bathroom <1)].iloc[:,1:]
# Out:
#                 Suburb            Address  Rooms Type      Price Method  \
# 188         Alphington        6 Naroon Rd      3    h  1485000.0     SP
# 381           Armadale    3/50 Denbigh Rd      2    u   546000.0     SP
# 679          Balaclava     5/11 Albion St      2    u   497500.0     PI
# 791             Balwyn     5 Shrimpton Ct      2    h  1010000.0     PI
# 1223    Bentleigh East    579 Warrigal Rd      3    h   700000.0      S
# 1402          Brighton          17 New St      3    h  1900000.0      S
# 1410          Brighton        1/5 Webb St      3    t  1067000.0      S
# 2107        Camberwell   5 Nicholsdale Rd      4    h  1400000.0     PI
# 2923       Elsternwick    5/29 Nepean Hwy      2    u   410000.0     VB
# 3521         Glen Iris         25 Hope St      2    h   845000.0      S
# 3546         Glen Iris        130 High St      4    h  1550000.0     PI
# 3558         Glen Iris    1/64 Edgar St N      2    u   545000.0      S
# ...

# %%
data.pivot_table(values: 'Price', index: 'SellerG')
# Out:
#   File "<ipython-input-98-69cc311cb3de>", line 1
#     data.pivot_table(values: 'Price', index: 'SellerG')
#                            ^
# SyntaxError: invalid syntax

# %%
data.head(111)

# %%
МЕТОД	СТАТИСТИЧЕСКИЙ ПАРАМЕТР
.count()	Количество непустых значений
.mean()	Среднее значение
.min()	Минимальное значение
.max()	Максимальное значение
.deviance()	Дисперсия
.std()	Стандартное отклонение
.sum()	Сумма
.quantile(x)	Квантиль уровня x
.nunique()	Число уникальных значений

# %%
df = pd.DataFrame([pd.Series(x) for x in df.teams])
df.columns = ['team_{}'.format(x+1) for x in df.columns]                                  #Столбцы названия автомат

# %%
import pandas as pd                                                                                                   !!!!!!!!!!!!!

d0 = pd.read_csv('c:/1/log.0.csv', sep = r'( |(?<=^\d{2})|:|,|>)', error_bad_lines=False)
d00 = pd.read_csv('c:/1/log.0.csv', sep = r'( |(?<=^\d{2})|,|>)', error_bad_lines=False)
dtip = pd.DataFrame({'date': (d0.iloc[:,0]), 'time' : (d00.iloc[:,2]), 'ip': (d0.iloc[:,60])})
dtip.to_csv('c:/1/dtip0.csv', sep = ';', index=True)
print('done 0')


d0 = pd.read_csv('c:/1/log.1.csv', sep = r'( |(?<=^\d{2})|:|,|>)', error_bad_lines=False)
d00 = pd.read_csv('c:/1/log.1.csv', sep = r'( |(?<=^\d{2})|,|>)', error_bad_lines=False)
dtip = pd.DataFrame({'date': (d0.iloc[:,0]), 'time' : (d00.iloc[:,2]), 'ip': (d0.iloc[:,60])})
dtip.to_csv('c:/1/dtip1.csv', sep = ';', index=True)
print('done 1')


d0 = pd.read_csv('c:/1/log.2.csv', sep = r'( |(?<=^\d{2})|:|,|>)', error_bad_lines=False)
d00 = pd.read_csv('c:/1/log.2.csv', sep = r'( |(?<=^\d{2})|,|>)', error_bad_lines=False)
dtip = pd.DataFrame({'date': (d0.iloc[:,0]), 'time' : (d00.iloc[:,2]), 'ip': (d0.iloc[:,60])})
dtip.to_csv('c:/1/dtip2.csv', sep = ';', index=True)
print('done 2')


d0 = pd.read_csv('c:/1/log.3.csv', sep = r'( |(?<=^\d{2})|:|,|>)', error_bad_lines=False)
d00 = pd.read_csv('c:/1/log.3.csv', sep = r'( |(?<=^\d{2})|,|>)', error_bad_lines=False)
dtip = pd.DataFrame({'date': (d0.iloc[:,0]), 'time' : (d00.iloc[:,2]), 'ip': (d0.iloc[:,60])})
dtip.to_csv('c:/1/dtip3.csv', sep = ';', index=True)
print('done 3')


d0 = pd.read_csv('c:/1/log.4.csv', sep = r'( |(?<=^\d{2})|:|,|>)', error_bad_lines=False)
d00 = pd.read_csv('c:/1/log.4.csv', sep = r'( |(?<=^\d{2})|,|>)', error_bad_lines=False)
dtip = pd.DataFrame({'date': (d0.iloc[:,0]), 'time' : (d00.iloc[:,2]фimport pandas as pd

d0 = pd.read_csv('c:/1/log.0.csv', sep = r'( |(?<=^\d{2})|:|,|>)', error_bad_lines=False)
d00 = pd.read_csv('c:/1/log.0.csv', sep = r'( |(?<=^\d{2})|,|>)', error_bad_lines=False)
dtip = pd.DataFrame({'date': (d0.iloc[:,0]), 'time' : (d00.iloc[:,2]), 'ip': (d0.iloc[:,60])})
dtip.to_csv('c:/1/dtip0.csv', sep = ';', index=False)
print('done 0')


d0 = pd.read_csv('c:/1/log.1.csv', sep = r'( |(?<=^\d{2})|:|,|>)', error_bad_lines=False)
d00 = pd.read_csv('c:/1/log.1.csv', sep = r'( |(?<=^\d{2})|,|>)', error_bad_lines=False)
dtip = pd.DataFrame({'date': (d0.iloc[:,0]), 'time' : (d00.iloc[:,2]), 'ip': (d0.iloc[:,60])})
dtip.to_csv('c:/1/dtip1.csv', sep = ';', index=False)
print('done 1')


d0 = pd.read_csv('c:/1/log.2.csv', sep = r'( |(?<=^\d{2})|:|,|>)', error_bad_lines=False)
d00 = pd.read_csv('c:/1/log.2.csv', sep = r'( |(?<=^\d{2})|,|>)', error_bad_lines=False)
dtip = pd.DataFrame({'date': (d0.iloc[:,0]), 'time' : (d00.iloc[:,2]), 'ip': (d0.iloc[:,60])})
dtip.to_csv('c:/1/dtip2.csv', sep = ';', index=False)
print('done 2')


d0 = pd.read_csv('c:/1/log.3.csv', sep = r'( |(?<=^\d{2})|:|,|>)', error_bad_lines=False)
d00 = pd.read_csv('c:/1/log.3.csv', sep = r'( |(?<=^\d{2})|,|>)', error_bad_lines=False)
dtip = pd.DataFrame({'date': (d0.iloc[:,0]), 'time' : (d00.iloc[:,2]), 'ip': (d0.iloc[:,60])})
dtip.to_csv('c:/1/dtip3.csv', sep = ';', index=False)
print('done 3')


d0 = pd.read_csv('c:/1/log.4.csv', sep = r'( |(?<=^\d{2})|:|,|>)', error_bad_lines=False)
d00 = pd.read_csv('c:/1/log.4.csv', sep = r'( |(?<=^\d{2})|,|>)', error_bad_lines=False)
dtip = pd.DataFrame({'date': (d0.iloc[:,0]), 'time' : (d00.iloc[:,2]), 'ip': (d0.iloc[:,60])})
dtip.to_csv('c:/1/dtip4.csv', sep = ';', index=False)
print('done 4')

from pathlib import Path
data_dir = Path("c:/1/1/")
df = pd.concat([pd.read_csv(f) for f in data_dir.glob("*.csv")], ignore_index=True)
df.to_csv("c:/1/result.csv", index=False)
print('All done')
), 'ip': (d0.iloc[:,60])})
dtip.to_csv('c:/1/dtip4.csv', sep = ';', index=True)
print('done 4')

from pathlib import Path
data_dir = Path("c:/1/1/")
df = pd.concat([pd.read_csv(f) for f in data_dir.glob("*.csv")], ignore_index=True)
df.to_csv("c:/1/result.csv", index=False)

# %%
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! лог атак и рейтинг атакующих

# %%
import pandas as pd                                                             #Несколько разделителей
d = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/log2.csv', header = None, sep = r'( |(?<=^\d{2})|:|,|>)', warn_bad_lines=True, error_bad_lines=False)
d2 = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/log2.csv', header = None, sep = r'( |(?<=^\d{2})|,|>)', warn_bad_lines=True, error_bad_lines=False)

date = (d2.iloc[:,0])
time = (d2.iloc[:,2])
ip = (d.iloc[:,60])

ndf = pd.DataFrame({'date':date, 'time': time, 'ip': ip})


display(ndf.head())
display(ndf.ip.value_counts().nlargest(10))
# display(ndf[(ndf['ip'].isin(['203.86.235.224']))])
display(ndf[ndf['ip'].str.contains('203')])






ni = (ndf.ip.value_counts())
nt = (ndf.time.value_counts())
nd = (ndf.date.value_counts())

# print(ni, nd)
# ndf.to_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/log2exit.csv', sep = ';')
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           date      time              ip
# 0  Nov/29/2022  02:30:03  203.86.235.224
# 1  Nov/29/2022  02:30:06  203.86.235.224
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ndf.pivot_table(values=ni, index=ni, columns=ni, aggfunc='mean').plot(kind = 'line')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-f41d450412d8> in <module>
#       1 import matplotlib.pyplot as plt
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 3 ndf.pivot_table(values=ni, index=ni, columns=ni, aggfunc='mean').plot(kind = 'line')
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    7949         from pandas.core.reshape.pivot import pivot_table
#    7950
# -> 7951         return pivot_table(
#    7952             self,
#    7953             values=values,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
# ...

# %%
/usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
  return func(*args, **kwargs)
185.233.95.113
185.233.95.113     3776
211.152.1.50       1495
163.53.90.66       1453
37.193.54.149      1021
221.181.73.49       711
47.92.213.76        202
94.250.245.94       150
163.30.173.96       100
176.115.196.74       94
178.173.38.93        92
78.30.195.20         84
91.194.246.1         83
37.193.129.158       82
91.221.102.122       81
89.175.98.94         81
82.200.88.38         81
94.250.245.93        74
77.245.97.110        60
88.99.26.58          60
95.64.133.198        60
94.250.245.12        48
94.250.245.103       35
202.107.225.190      34
194.44.130.38        22
176.12.98.222         7
85.143.143.131        3
135.125.188.58        1
52.139.168.113        1
dtype: int64

# %%
                                                                                                                  #Мельбурн

# %%
import pandas as pd
melb_data = pd.read_csv('https://raw.githubusercontent.com/kuchsk/skillfactory/main/melb_data.csv', sep=',') #, index_col = 'Type') # , index_col = ['Coordinates', 'YearBuilt'])
# display(melb_data.index[15]])
m= melb_data
# melb_data.iloc[0:1]
k=(int(m.Landsize[3521:3522])/int(m.Landsize[1690:1691]))
print(k)
# melb_data.head()
# k = melb_data({'prise'}, index = (15))
# display(k)
# display(melb_data.sample())
display(m.Coordinates)
# Out:
# 2.7857142857142856
# 0          -37.7996, 144.9984
# 1          -37.8079, 144.9934
# 2          -37.8093, 144.9944
# 3          -37.7969, 144.9969
# 4          -37.8072, 144.9941
#                  ...
# 13575    -37.90562, 145.16761
# 13576    -37.85927, 144.87904
# 13577    -37.85274, 144.88738
# 13578    -37.85908, 144.89299
# 13579    -37.81188, 144.88449
# Name: Coordinates, Length: 13580, dtype: object

# %%
# Read the csv file with columns where length of column name > 10
df = pd.read_csv("data.csv", usecols=lambda x: len(x)>10)
df.head()

# %%
# Read the csv file with 5 rows
df = pd.read_csv("data.csv", nrows=5)
df

# %%
display(melb_data.sample(n = 2))
# Out:
#        index       Suburb         Address  Rooms Type      Price Method  \
# 11368  11368  Forest Hill  2 Thornhill Dr      6    h  1234000.0      S
# 995      995     Box Hill  6 Archibald St      3    h  4000000.0     VB
#
#          SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 11368        Ray  15/07/2017      15.4  ...  2.0     579.0         126.0
# 995    Lindellas  18/06/2016      13.1  ...  2.0     763.0         120.0
#
#        YearBuilt  CouncilArea  Lattitude  Longtitude            Regionname  \
# 11368     1970.0   Whitehorse  -37.83508   145.16936  Eastern Metropolitan
# 995       1945.0   Whitehorse  -37.81660   145.12150  Eastern Metropolitan
#
#        Propertycount           Coordinates
# 11368         4385.0  -37.83508, 145.16936
# 995           4605.0    -37.8166, 145.1215
#
# [2 rows x 23 columns]

# %%
display(melb_data.sample(frac = 0.01))

# %%
from pandas.core.window.expanding import Axis
display(m.iloc[15] )
# Out:
# index                               15
# Suburb                      Abbotsford
# Address                  16 William St
# Rooms                                2
# Type                                 h
# Price                        1310000.0
# Method                               S
# SellerG                         Jellis
# Date                        15/10/2016
# Distance                           2.5
# Postcode                          3067
# Bedroom                            2.0
# Bathroom                           1.0
# Car                                2.0
# Landsize                         238.0
# BuildingArea                      97.0
# YearBuilt                       1890.0
# CouncilArea                      Yarra
# Lattitude                      -37.809
# Longtitude                    144.9976
# Regionname       Northern Metropolitan
# Propertycount                   4019.0
# Coordinates          -37.809, 144.9976
# Name: 15, dtype: object

# %%
display(melb_data.head())
melb_data.tail(7)
melb_data.shape
melb_data.info()
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]

# %%
m.describe().loc[:,['Distance', 'BuildingArea', 'Price']]
# Out:
#            Distance  BuildingArea         Price
# count  13580.000000  13580.000000  1.358000e+04
# mean      10.137776    139.633972  1.075684e+06
# std        5.868725    392.217403  6.393107e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        6.100000    122.000000  6.500000e+05
# 50%        9.200000    126.000000  9.030000e+05
# 75%       13.000000    129.940000  1.330000e+06
# max       48.100000  44515.000000  9.000000e+06

# %%
melb_data.describe(include=['object'])
# Out:
#            Suburb           Address   Type Method SellerG        Date  \
# count       13580             13580  13580  13580   13580       13580
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#        CouncilArea             Regionname         Coordinates
# count        12211                  13580               13580
# unique          33                      8               13097
# top       Moreland  Southern Metropolitan  -37.8361, 144.9966
# freq          1163                   4695                  12

# %%
melb_data['Regionname'].value_counts()
# Out:
# Southern Metropolitan         4695
# Northern Metropolitan         3890
# Western Metropolitan          2948
# Eastern Metropolitan          1471
# South-Eastern Metropolitan     450
# Eastern Victoria                53
# Northern Victoria               41
# Western Victoria                32
# Name: Regionname, dtype: int64

# %%
melb_data['Regionname'].value_counts(normalize=True)
# Out:
# Southern Metropolitan         0.345729
# Northern Metropolitan         0.286451
# Western Metropolitan          0.217084
# Eastern Metropolitan          0.108321
# South-Eastern Metropolitan    0.033137
# Eastern Victoria              0.003903
# Northern Victoria             0.003019
# Western Victoria              0.002356
# Name: Regionname, dtype: float64

# %%
import pandas as pd
data = pd.DataFrame([[0,1], [1, 0], [1, 1]], columns=['А', 'B'])
print(data.shape)
print(data.info())
# Out:
# (3, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   А       3 non-null      int64
#  1   B       3 non-null      int64
# dtypes: int64(2)
# memory usage: 176.0 bytes
# None

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
from unicodedata import normalize
import pandas as pd
m = pd.read_csv('https://raw.githubusercontent.com/kuchsk/skillfactory/main/melb_data.csv', sep=',') #, index_col = 'Type') # , index_col = ['Coordinates', 'YearBuilt'])
# display(m.head(5))
# display(m.tail(2))
display(m.shape)        #размер - строк, столбцов
# display(melb_data.index[15]])
# display(m.info())       #инфо
m['Car'] = m['Car'].astype('int64')            #сменить тип столбца
# m.describe().loc[:, ['Car', 'Price']]
# m.describe(include = ['int64'])            #для типов
# m['Regionname'].value_counts(normalize=True)*100               #Сколько значений в
# display(m['CouncilArea'].isna().sum())                           #Сколько значений Na
# display(m.Price.mode()/m.Price.median())                #Среднее/на медианное
# display(m.Distance.describe())
# display(m['BuildingArea'].median())                             #Средняя площадь здания
# display(tuple(x for x in m.Distance.unique() if x ==0))              #Как минимум одно здание находится в центре Мельбурна
# display(list(m.groupby(['Regionname', 'Coordinates'])))
# У скольких совпадают координаты
x = []; xset = set()
for x2 in m.Coordinates:
  x.append(x2)
  xset.add(x2)
display(len(x)- len(xset))

# display(m.Suburb.value_counts())
# display(m.Suburb.isna().sum())

display(m.Type.value_counts(normalize)*100)



# display(x for x in m.Coordinates.unique() if counts x > 1)
# Out:
# (13580, 23)
# [(('Eastern Metropolitan', '-37.68508, 145.1395'),
#          index     Suburb       Address  Rooms Type      Price Method   SellerG  \
#   10517  10517  St Helena  11 Erinne Ct      5    h  1387000.0      S  Morrison
#
#                Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
#   10517  27/05/2017      16.1  ...    3    1348.0         370.0     2005.0
#
#          CouncilArea  Lattitude  Longtitude            Regionname  \
#   10517      Banyule  -37.68508    145.1395  Eastern Metropolitan
#
#          Propertycount          Coordinates
#   10517          915.0  -37.68508, 145.1395
#
#   [1 rows x 23 columns]),
#  (('Eastern Metropolitan', '-37.68739, 145.14437'),
#          index        Suburb       Address  Rooms Type     Price Method  \
#   12488  12488  Eltham North  15 Marian Ct      4    h  950000.0     PI
#
#             SellerG       Date  Distance  ...  Car  Landsize  BuildingArea  \
# ...

# %%
data = pd.DataFrame([[0,1], [1, 0], [1, 1]], columns=['А', 'B'])
display(data)
display(m['CouncilArea'].isna().sum())
# Out:
#    А  B
# 0  0  1
# 1  1  0
# 2  1  1
# 1369

# %%
# Архив: «Основы Numpy и Pandas». Спикер: Мария Липчанская
import pandas as pd
s = pd.Series(data = [1,2,3,4,5], index = 'one two three four five'.split())
# display(s, s['two'])
s.describe().T
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
                                                                                                              # !!!!!!!! Конец задания

# %%
.count()	Количество непустых значений
.mean()	Среднее значение
.min()	Минимальное значение
.max()	Максимальное значение
.deviance()	Дисперсия
.std()	Стандартное отклонение
.sum()	Сумма
.quantile(x)	Квантиль уровня x
.nunique()	Число уникальных значений
.value_counts(normalize=True)

# %%
# !Олег Булыгин вебинар !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
import pandas as pd
my_series = pd.Series([1,2,3,4,5,6])
display(my_series, my_series **2)

# %%
my_df = pd.DataFrame({
    'City': ['MSK', 'SPB', 'EKB'],
    'Temp': [-3, -5, -2],
    'State': ['Cloudly', 'Clear', 'Snow']
})
display(my_df )
# Out:
#   City  Temp    State
# 0  MSK    -3  Cloudly
# 1  SPB    -5    Clear
# 2  EKB    -2     Snow

# %%
pd.read_csv('c:\11111111.csv')
pd.read_excel('c:\1111.xlsx', sheet_name = 'страница')
pd.read_html('c:\1111111.html')
df.to_csv('c:\1111111111111.csv')

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/obulygin/SkillFactory/main/train.csv')
df
df.to_csv('titanic.csv')
# df.info()
# df.tail(1)
# df.head(1)
df.shape              #форма
df.describe()
display(df['Age'].mean(), df['Age'].median, df['Age'].mode([0]), df['Age'].std(), df['Age'].var())
# Out:
# 29.69911764705882
# <bound method NDFrame._add_numeric_operations.<locals>.median of 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64>
# 0    24.0
# dtype: float64
# 14.526497332334042
# 211.01912474630802

# %%
df[['Pclass', 'Sex']].value_counts()
# Out:
# Pclass  Sex
# 3       male      347
#         female    144
# 1       male      122
# 2       male      108
# 1       female     94
# 2       female     76
# dtype: int64

# %%
df[['Age', 'Sex']].value_counts(normalize=True)*100
# Out:
# Age   Sex
# 19.0  male      2.521008
# 25.0  male      2.521008
# 28.0  male      2.521008
# 21.0  male      2.380952
# 24.0  female    2.240896
#                   ...
# 32.5  male      0.140056
# 34.5  male      0.140056
# 36.5  male      0.140056
# 37.0  female    0.140056
# 80.0  male      0.140056
# Length: 145, dtype: float64

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df[(df['Age'] >30) & (df['Age'] <31)]
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 767          768         0       3          Mangan, Miss. Mary  female  30.5
# 814          815         0       3  Tomlin, Mr. Ernest Portage    male  30.5
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 767      0      0  364850  7.75   NaN        Q
# 814      0      0  364499  8.05   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Sex'].value_counts(normalize = True)*100
# Out:
# male      64.758698
# female    35.241302
# Name: Sex, dtype: float64

# %%
df[['Sex','Pclass']].value_counts(normalize = True)*100
# Out:
# Sex     Pclass
# male    3         38.945006
# female  3         16.161616
# male    1         13.692480
#         2         12.121212
# female  1         10.549944
#         2          8.529742
# dtype: float64

# %%
df.loc[1:5, ['Name', 'Sex']]                                                                      #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!вырезка по строке и столбцу
# Out:
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male

# %%
df.loc[99:199:18,['Name','Pclass']]
# Out:
#                                 Name  Pclass
# 99                 Kantor, Mr. Sinai       2
# 117  Turpin, Mr. William John Robert       2
# 135               Richard, Mr. Emile       2
# 153  van Billiard, Mr. Austin Blyler       3
# 171             Rice, Master. Arthur       3
# 189              Turcin, Mr. Stjepan       3

# %%
import pandas as pd             #!!!!!!!!!!!!!!
df = pd.read_csv('https://raw.githubusercontent.com/obulygin/SkillFactory/main/train.csv')
df['Age'] >30
df[(df['Age'] > 30) & (df['Age'] < 32) & (df['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 215          216         1       1               Newell, Miss. Madeleine
# 318          319         1       1              Wick, Miss. Mary Natalie
# 671          672         0       1                Davidson, Mr. Thornton
# 690          691         1       1               Dick, Mr. Albert Adrian
# 867          868         0       1  Roebling, Mr. Washington Augustus II
#
#         Sex   Age  SibSp  Parch      Ticket      Fare Cabin Embarked
# 215  female  31.0      1      0       35273  113.2750   D36        C
# 318  female  31.0      0      2       36928  164.8667    C7        S
# 671    male  31.0      1      0  F.C. 12750   52.0000   B71        S
# 690    male  31.0      1      0       17474   57.0000   B20        S
# 867    male  31.0      0      0    PC 17590   50.4958   A24        S

# %%
df[(df['Name'].str.contains('Jane'))]
# Out:
#      PassengerId  Survived  Pclass  \
# 486          487         1       1
# 506          507         1       2
# 612          613         1       3
# 754          755         1       2
# 875          876         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 486  Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)  female  35.0      1
# 506    Quick, Mrs. Frederick Charles (Jane Richards)  female  33.0      0
# 612                      Murphy, Miss. Margaret Jane  female   NaN      1
# 754                 Herman, Mrs. Samuel (Jane Laver)  female  48.0      1
# 875                 Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
#
#      Parch  Ticket    Fare Cabin Embarked
# 486      0   19943  90.000   C93        S
# 506      2   26360  26.000   NaN        S
# 612      0  367230  15.500   NaN        Q
# 754      2  220845  65.000   NaN        S
# 875      0    2667   7.225   NaN        C

# %%
display(df[(df['Embarked'] == 'S')].Age.mean())
display(df[(df['Embarked'] == 'S')].Sex.value_counts())
display(df[(df['Embarked'] == 'S')].Pclass.value_counts())
# Out:
# 29.44539711191336
# male      441
# female    203
# Name: Sex, dtype: int64
# 3    353
# 2    164
# 1    127
# Name: Pclass, dtype: int64

# %%
df.sort_values(['Age','Sex'], ascending =False).head(2)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 630  male  80.0      0      0   27042  30.000   A23        S
# 851  male  74.0      0      0  347060   7.775   NaN        S

# %%
df[(df['Age'].isna())]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df['Age'].isna().sum()
# Out:
# 177

# %%
# Пропуски во всех столбцах
for col in df.columns:
  pct_missing = df[col].isna().mean()
  display(f'{col} - {pct_missing: .2%}')

# %%
df.dropna() # - удаление пустышек
df.dropna(thresh = 10).info()  # удалить те, где 10 заполнены, а остальные пропущены
df.dropna(axis =1).info()       # Удалить столбцы, где есть пропуски
df.drop(['Cabin'], axis =1).info()       # Удалить просто столбец

# %%
df.groupby('Sex')['Age'].mean()

# %%
df.groupby(['Sex', 'Pclass'])['Age'].median()
# Out:
# Sex     Pclass
# female  1         35.0
#         2         28.0
#         3         21.5
# male    1         40.0
#         2         30.0
#         3         25.0
# Name: Age, dtype: float64

# %%
df.dropna(subset=['Age']), axis = 1).info()

# %%
df.groupby(['Sex','Pclass'])['Age'].median()
# Out:
# Sex     Pclass
# female  1         35.0
#         2         28.0
#         3         21.5
# male    1         40.0
#         2         30.0
#         3         25.0
# Name: Age, dtype: float64

# %%
df.groupby(['Sex','Pclass']).agg(['median','max'])
# Out:
#               PassengerId      Survived        Age        SibSp      Parch  \
#                    median  max   median max median   max median max median
# Sex    Pclass
# female 1            447.0  888      1.0   1   35.0  63.0    0.0   3    0.0
#        2            439.5  881      1.0   1   28.0  57.0    0.0   3    0.0
#        3            376.0  889      0.5   1   21.5  63.0    0.0   8    0.0
# male   1            480.5  890      0.0   1   40.0  80.0    0.0   3    0.0
#        2            416.5  887      0.0   1   30.0  70.0    0.0   2    0.0
#        3            466.0  891      0.0   1   25.0  74.0    0.0   8    0.0
#
#                        Fare
#               max    median       max
# Sex    Pclass
# female 1        2  82.66455  512.3292
#        2        3  22.00000   65.0000
#        3        6  12.47500   69.5500
# male   1        4  41.26250  512.3292
#        2        2  13.00000   73.5000
#        3        5   7.92500   69.5500

# %%
df.groupby(['Sex','Pclass'])['Age'].agg('median','max')
# Out:
# Sex     Pclass
# female  1         35.0
#         2         28.0
#         3         21.5
# male    1         40.0
#         2         30.0
#         3         25.0
# Name: Age, dtype: float64

# %%
tr = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/train.csv')

# %%
from traitlets.config.application import Instance
# from pandas.core.common import all_not_none
#Мастерская
import pandas as pd
d = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/ih.csv')
# d.iloc[1:11, 1:11].median()
d.head()
# d[(d["location"] != "Samoa") & (d.sex != "Male") & (d.age == 'All Ages')]
# d.describe()#include = 'all')
# d[(d.sex == 'Male')]

# d.groupby(['sex', 'cause']).agg([max, 'mean'])
# d.groupby([(d.sex == 'Male') & (d.val > 60) & (d['year'] >=2009)]).agg('max', 'median')
d[(d['cause'].str.contains('A') & (d.year > 2018))]                    #!!!!фильтр по части названия столбца


d[~(d['val']>1000)]

d.drop('measure', axis = 1, inplace = True)

# d.drop(['sex', 'val'], axis =1, inplace = True)
d['val2'] = d['val'].round(decimals =1)                                     #округление и копия столбца
ddd= d.describe().T
ddd['50%']['val']
d[(d['val'] > 1111)].value_counts().T
d[(d.sex == "Male")]['val']

df_cause = d.groupby('cause').agg({'year':['count'], 
                                    'val':['mean', 'median']})
# display(df_cause)
df_cause['val']['mean'].sort_values()

df_gender = d.groupby(['cause', 'sex']).agg({'val': ['mean', 'median']})
display(df_gender)
# Out:
#                                             val
#                                            mean      median
# cause                        sex
# Cardiovascular diseases      Both    245.038277  199.178194
#                              Female  242.429336  181.537109
#                              Male    247.079954  204.731125
# Chronic respiratory diseases Both     31.783867   27.341307
#                              Female   27.003046   21.051406
# ...                                         ...         ...
# Transport injuries           Female    9.329241    7.783497
#                              Male     27.497411   25.001762
# Unintentional injuries       Both     24.338395   21.899341
#                              Female   16.590452   14.334211
#                              Male     32.185398   28.135601
#
# [63 rows x 2 columns]

# %%
d
# Out:
#        location     sex       age                                    cause  \
# 0         Samoa    Male  All Ages             Chronic respiratory diseases
# 1         Samoa  Female  All Ages             Chronic respiratory diseases
# 2         Samoa    Both  All Ages             Chronic respiratory diseases
# 3         Samoa    Male  All Ages           Skin and subcutaneous diseases
# 4         Samoa  Female  All Ages           Skin and subcutaneous diseases
# ...         ...     ...       ...                                      ...
# 257035  Comoros  Female  All Ages  Neglected tropical diseases and malaria
# 257036  Comoros    Both  All Ages  Neglected tropical diseases and malaria
# 257037  Comoros    Male  All Ages             Chronic respiratory diseases
# 257038  Comoros  Female  All Ages             Chronic respiratory diseases
# 257039  Comoros    Both  All Ages             Chronic respiratory diseases
#
#        metric  year        val      upper      lower  val2
# ...

# %%
# d.nlargest(7, 'upper')                  !!!!!!!!!!!!больше меньше
# d.nsmallest(5, 'val')


t = d.groupby('cause').agg({'year': 'count',
                        'val': ['mean', 'median'], 'val2': 'mean'})
t.val['mean'].sort_values(ascending = False)
# Out:
# cause
# Cardiovascular diseases                         244.849189
# Neoplasms                                       127.104386
# Respiratory infections and tuberculosis          63.475924
# Diabetes and kidney diseases                     47.226334
# HIV/AIDS and sexually transmitted infections     41.961014
# Maternal and neonatal disorders                  37.557121
# Digestive diseases                               34.127663
# Chronic respiratory diseases                     31.818755
# Enteric infections                               27.374869
# Neurological disorders                           25.430591
# Unintentional injuries                           24.371415
# Self-harm and interpersonal violence             21.545159
# Neglected tropical diseases and malaria          19.971543
# Other non-communicable diseases                  19.209209
# Transport injuries                               18.432300
# Other infectious diseases                        16.805678
# ...

# %%
tt = d.groupby(['cause','sex']).agg({'val': ['mean', 'median']})
display(tt)
display(tt.xs('Transport injuries', level = 'cause'))
tt.xs('Transport injuries', level = 'cause')['val'].loc['Male', 'mean']
# Out:
#                                             val
#                                            mean      median
# cause                        sex
# Cardiovascular diseases      Both    245.038277  199.178194
#                              Female  242.429336  181.537109
#                              Male    247.079954  204.731125
# Chronic respiratory diseases Both     31.783867   27.341307
#                              Female   27.003046   21.051406
# ...                                         ...         ...
# Transport injuries           Female    9.329241    7.783497
#                              Male     27.497411   25.001762
# Unintentional injuries       Both     24.338395   21.899341
#                              Female   16.590452   14.334211
#                              Male     32.185398   28.135601
#
# [63 rows x 2 columns]
#               val
#              mean     median
# sex
# Both    18.470248  16.414021
# Female   9.329241   7.783497
# ...

# %%
ttp= d.pivot_table(values='val', index=['location', 'year'], columns='cause', aggfunc='mean', fill_value=None, margins=True, dropna=True, margins_name='All', observed=False, sort=True)
ttp
# ttp.loc['Albania', 'Digestive diseases']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
d[(d['location'] == 'Russian Federation') & (d['cause'].str.contains('HI')) &(d['sex'] == 'Both')].pivot_table(values='val', index=['location', 'year'], columns='cause', aggfunc='mean', fill_value=None, margins=True, dropna=True, margins_name='All', observed=False, sort=True).plot(kind = 'line')

# %%
d[(d['location'].str.contains('Rus')) & (d['cause'].str.contains('Ca')) &(d['sex'] == 'Both')].pivot_table(values='val', index=['location', 'year'], columns='cause', aggfunc='mean', fill_value=None, margins=True, dropna=True, margins_name='All', observed=False, sort=True).plot(kind = 'line')
plt.ylabel = ('Deaths per 100 000')
plt.title = ('in Rus')

# %%
df_bar = d[(d['sex'].isin(['Male', 'Female'])) & (d['year'] == 2019)].pivot_table(values = 'val', index = 'cause', columns = 'sex', aggfunc = 'mean', fill_value = None, margins=False, dropna = True)
df_bar.plot(kind = 'bar')

# %%
# !pip install plotly==5.3.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 23.9 MB 71.5 MB/s
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# ...

# %%
import pandas as pd                                   #Часть из Рыситкова Андрея
import numpy as np

import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

games_df=pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/vgsales.csv')
data = games_df.copy()
data = data[data['Year_of_Release'].notna()]
data['User_Score'] = data.User_Score.replace('tbd', np.NaN).astype('float64')
#data['Critic_Score'] = data.Critic_Score.replace('tbd', np.NaN).astype('float64')

data['User_Count'] = data.User_Count.replace('<NA>', np.NaN).astype('float64')
data['Critic_Count'] = data.Critic_Count.replace('<NA>', np.NaN).astype('float64')

data['Year_of_Release'] = data.Year_of_Release.astype('Int64')

data['User_Score'] = data.User_Score * 10
#data = data.drop(['User_Count','Critic_Count'], axis=1)
data = data.sort_values('Year_of_Release', ascending=True, ignore_index=True)
data.tail()
# Out:
#                                                    Name Platform  \
# 16445                           Rise of the Tomb Raider      PS4
# 16446  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16447  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16448                  Brothers Conflict: Precious Baby      PSV
# 16449                            Imagine: Makeup Artist       DS
#
#        Year_of_Release         Genre     Publisher  NA_Sales  EU_Sales  \
# 16445             2016     Adventure   Square Enix      0.23      0.53
# 16446             2017  Role-Playing          Sega      0.00      0.00
# 16447             2017  Role-Playing          Sega      0.00      0.00
# 16448             2017        Action  Idea Factory      0.00      0.00
# 16449             2020    Simulation       Ubisoft      0.27      0.00
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 16445      0.04         0.14          0.94           NaN           NaN
# ...

# %%
import cufflinks as cf
cf.set_config_file(offline=True)
df = pd.DataFrame(np.random.rand(6, 3), columns=['A', 'B', 'C'])
df.iplot(kind='bar', barmode='stack', title='Stacked Bar Chart with Random Data')
my_fig = df.iplot(kind='bar', barmode='stack', title='Stacked Bar Chart with Random Data', asFigure=True)
my_fig.layout.yaxis = dict(title='Members', range=[0, 600])

# %%
fig = px.histogram(
    data,
    x='val',
    y='cause',
    color = 'location',
    title='Distribution of user count by genre',
    width=700,
    height=500,
)
fig.show()

# %%
fig = px.histogram(
    data,
    x='User_Count',
    y='Genre',
    color='Genre',
    title='Distribution of user count by genre',
    width=700,
    height=500,
)
fig.show()

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length",
                 color="species", color_discrete_sequence=px.colors.qualitative.Antique)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for cls in sorted(tr['Pclass'].unique()):
  print('Класс', cls)
  for sex in tr['Sex'].unique():
    if sex == 'male':
      print('Данные о мужчинах')
    else:
      print('Данные о женщинах')
    print(tr[(tr['Sex'] == sex)&(tr['Pclass'] == cls)]['Survived'].value_counts())

# %%
tr.groupby(by = 'Survived')['Age'].mean()
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
tr.groupby(['Survived','Pclass'])['Age'].value_counts()
# Out:
# Survived  Pclass  Age
# 0         1       47.0    4
#                   45.0    3
#                   50.0    3
#                   19.0    2
#                   24.0    2
#                          ..
# 1         3       38.0    1
#                   39.0    1
#                   44.0    1
#                   45.0    1
#                   63.0    1
# Name: Age, Length: 264, dtype: int64

# %%
tr.groupby(['Sex','Pclass'])['Survived'].value_counts()
# Out:
# Sex     Pclass  Survived
# female  1       1            91
#                 0             3
#         2       1            70
#                 0             6
#         3       0            72
#                 1            72
# male    1       0            77
#                 1            45
#         2       0            91
#                 1            17
#         3       0           300
#                 1            47
# Name: Survived, dtype: int64

# %%
tr.groupby('Name')['Survived'].value_counts()
# Out:
# Name                                   Survived
# Abbing, Mr. Anthony                    0           1
# Abbott, Mr. Rossmore Edward            0           1
# Abbott, Mrs. Stanton (Rosa Hunt)       1           1
# Abelson, Mr. Samuel                    0           1
# Abelson, Mrs. Samuel (Hannah Wizosky)  1           1
#                                                   ..
# de Mulder, Mr. Theodore                1           1
# de Pelsmaeker, Mr. Alfons              0           1
# del Carlo, Mr. Sebastiano              0           1
# van Billiard, Mr. Austin Blyler        0           1
# van Melkebeke, Mr. Philemon            0           1
# Name: Survived, Length: 891, dtype: int64

# %%
tr[tr['Fare']>0].groupby('Pclass')['Fare'].agg(['min', 'mean', 'max'])
# Out:
#             min       mean       max
# Pclass
# 1        5.0000  86.148874  512.3292
# 2       10.5000  21.358661   73.5000
# 3        4.0125  13.787875   69.5500

# %%
tr.groupby(['Pclass','Age'])['Fare'].agg(['min','max'])

# %%
tr.groupby(['Pclass','Sex'])['Fare'].agg(['min', 'median', 'max'])
# Out:
#                    min    median       max
# Pclass Sex
# 1      female  25.9292  82.66455  512.3292
#        male     0.0000  41.26250  512.3292
# 2      female  10.5000  22.00000   65.0000
#        male     0.0000  13.00000   73.5000
# 3      female   6.7500  12.47500   69.5500
#        male     0.0000   7.92500   69.5500

# %%
test = tr.pivot_table(values='Fare', index='Pclass', columns='Survived', aggfunc=['min', 'mean', 'max'], fill_value=None, margins=False, dropna=True, margins_name='All', observed=False, sort=True)
test['mean'][0]
# Out:
# Pclass
# 1    64.684007
# 2    19.412328
# 3    13.669364
# Name: 0, dtype: float64

# %%
tr.groupby(['Pclass','SibSp'])['Survived'].agg('mean')

# %%
tr.pivot_table(values='SibSp', index='Pclass', columns='Survived', aggfunc=['mean'], fill_value=None, margins=False, dropna=True, margins_name='All', observed=False, sort=True)
# Out:
#               mean
# Survived         0         1
# Pclass
# 1         0.287500  0.492647
# 2         0.319588  0.494253
# 3         0.672043  0.436975

# %%
df3 = df.merge(df2, on = 'Sex')

# %%
tr[(tr['Age'] > 18)&(tr['Fare'] != 0)].agg(['min', 'max'])
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# min            1         0       1              Abbing, Mr. Anthony  female
# max          891         1       3  van Billiard, Mr. Austin Blyler    male
#
#       Age  SibSp  Parch     Ticket      Fare
# min  19.0      0      0     110152    4.0125
# max  80.0      3      6  WE/P 5735  512.3292

# %%
tr[(tr['Age'] > 18)&(tr['Fare'] != 0)].Fare.min()
# Out:
# 4.0125

# %%
tr[(tr['Pclass'] ==1)&(tr['Fare']!=0)].Fare.mean()
# Out:
# 86.14887440758294

# %%
tr[(tr['Sex'] == 'male')].Survived.value_counts()
# Out:
# 0    468
# 1    109
# Name: Survived, dtype: int64

# %%
test = data.pivot_table(values='Price', index='SellerG', columns=None, aggfunc=['count'], fill_value=None, margins=False, dropna=True, margins_name='All', observed=False, sort=True).T
test['Nelson']
# Out:
# count  Price    2002
# Name: Nelson, dtype: int64

# %%
import pandas as pd
# data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv')
data = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/melb_data.csv')
display(data[(data["Price"] > 3000000) & (data.SellerG == 'Nelson')].loc[:,'Price':'SellerG':2])
display(data[(data["Price"] > 3000000) & (data.SellerG == 'Nelson')].loc[:,'Price':'SellerG':2].count())
# Out:
#            Price SellerG
# 2553   4011000.0  Nelson
# 2579   3400000.0  Nelson
# 6734   3900000.0  Nelson
# 7695   3450000.0  Nelson
# 11023  3200000.0  Nelson
# Price      5
# SellerG    5
# dtype: int64

# %%
data[(data.BuildingArea ==0)].Price.min()
# Out:
# 412500.0

# %%
import pandas as pd
data = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/melb_data.csv')

print(f'Какова средняя цена объектов недвижимости в таблице melb_data с ценой менее одного миллиона, \n в которых либо количество комнат больше пяти, либо здание моложе 2015 года?')
k = data[(data.Price <1000000) & ((data.Rooms > 5) | (data.YearBuilt > 2015))]
print('Среднее')
display(k.Price.mean().round(0))

print('Перепроверим')
print('Сумма прайсов ', k.Price.sum(), 'Количество прайсов', k.Price.count())
print('Среднее')
display((k.Price.sum()/k.Price.count()).round(0))

# display(k[['Price', 'Rooms', 'YearBuilt']])
# display(data.iloc[:, 1:7].sort_values(['Price'], ascending = False))
# data.pivot_table(values='Price', index=['Rooms', 'YearBuilt'], aggfunc='mean', fill_value=None, margins=True, dropna=True, margins_name='All', observed=False, sort=True)
data.nlargest(5, 'Price')
# Out:
# Какова средняя цена объектов недвижимости в таблице melb_data с ценой менее одного миллиона,
#  в которых либо количество комнат больше пяти, либо здание моложе 2015 года?
# Среднее
# 769239.0
# Перепроверим
# Сумма прайсов  33846500.0 Количество прайсов 44
# Среднее
# 769239.0
#        index       Suburb         Address  Rooms Type      Price Method  \
# 12094  12094     Mulgrave     35 Bevis St      3    h  9000000.0     PI
# 7692    7692   Canterbury  49 Mangarra Rd      5    h  8000000.0     VB
# 9575    9575     Hawthorn    49 Lisson Gr      4    h  7650000.0      S
# 3616    3616          Kew     15 Barry St      6    h  6500000.0      S
# 12557  12557  Middle Park     136 Page St      5    h  6400000.0      S
#
#             SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 12094          Hall  29/07/2017      18.8  ...  1.0     744.0         117.0
# 7692      Sotheby's  13/05/2017       9.0  ...  4.0    2079.0         464.3
# ...

# %%
import pandas as pd
data = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/melb_data.csv')
data[(data.Type == 'h') & (data.Price < 3000000)].Regionname.value_counts()
# Out:
# Northern Metropolitan         2737
# Southern Metropolitan         2520
# Western Metropolitan          2286
# Eastern Metropolitan          1167
# South-Eastern Metropolitan     387
# Eastern Victoria                50
# Northern Victoria               41
# Western Victoria                32
# Name: Regionname, dtype: int64

# %%
from pandas.core.dtypes.dtypes import Dtype
import pandas as pd
s = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/students_performance.csv')
s.head()
# ss = s[(s.gender == 'male')]
# display(s.info())
# display(len(list(ss.select_dtypes(include=['object']).columns)))
# display(s.iloc[:,1:2].value_counts())
# display((s[s['test preparation course'] !='none']).['reading score'].mean())
# display((s[s['test preparation course'] !='none']).iloc[:,6:7].mean())
# display((s[s['test preparation course'] !='none']).iloc[:,6:7])
# display((s['math score'] == 0).value_counts())
# display(s[s.lunch == 'standard'].iloc[:,5:6].mean())
# display(s['parental level of education'].value_counts(normalize = True)*100)
# display(abs((s[s['race/ethnicity']== 'group A']['writing score'].median())-(s[s['race/ethnicity']== 'group C']['writing score'].mean())).round(0))
# display(pd.isna(s).value_counts())
s.describe(include=['object'])
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       642

# %%
# Это skillfactory https://lms.skillfactory.ru/courses/course-v1:SkillFactory+DSPR-2.0+14JULY2021/courseware/adcad86c8b6c4e1299c49876a3024181/896fdb5831654c3bb6ca5590f2079ba4/?child=first

import pandas as pd

melb_data = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/melb_data_ps.csv', sep=',')
melb_data.head()
melb_data.drop(['Coordinates', 'index'], inplace = True, axis = 1)
m = melb_data
m.head()

total_rooms = m.Rooms + m.Bedroom + m.Bathroom
# display(total_rooms)

m['MeanRoomsSquare'] = m.BuildingArea/total_rooms
# display(m.head())
diff_area = m.BuildingArea -m.Landsize
sum_area = m.BuildingArea+m.Landsize
m['AreaRatio'] = diff_area/sum_area
# display(m.head())

import time
start_time = time.time()

price_square = melb_data['Price'] **2
display(price_square)

print("--- %s seconds ---" % (time.time() - start_time))
melb_df = melb_data.copy()
# Out:
# 0        2.190400e+12
# 1        1.071225e+12
# 2        2.146225e+12
# 3        7.225000e+11
# 4        2.560000e+12
#              ...
# 13575    1.550025e+12
# 13576    1.062961e+12
# 13577    1.368900e+12
# 13578    6.250000e+12
# 13579    1.651225e+12
# Name: Price, Length: 13580, dtype: float64
# --- 0.004728078842163086 seconds ---

# %%
import pandas as pd
melb_df = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/melb_data_ps.csv', sep=',')

display(melb_df.info())
x119 = melb_df.Suburb.value_counts()[:119]

melb_df['Suburb'] = melb_df['Suburb'].apply(lambda x: x if x in xx else 'other')
melb_df['Suburb'] = melb_df['Suburb'].astype('category')
display(melb_df.info())
# Out:
#   File "<ipython-input-19-222e3894b9fd>", line 7
#     melb_df['Suburb'] = melb_df['Suburb'].apply(lambda x: 'pass' if x not in (xx))
#                                                                                  ^
# SyntaxError: invalid syntax

# %%
#Задание
import pandas as pd
c = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/citibike-tripdata.csv')
# display(c.head(2))
# display(c['start station id'].isnull().value_counts())
# display(c.starttime.describe())
# display(sorted(set(c['birth year'])))
c['year'] = pd.to_datetime(c.starttime)
# display(sorted(set(c.year.dt.year-c['birth year'])))
# display(c['start station name'].value_counts().nsmallest(1))
# display(c['end station name'].value_counts()[:1])
# display(c.info())
# display((2018-c['birth year']).apply(lambda x: x >60).value_counts())

# c['start'] =pd.to_datetime(c.starttime)
# c['stop'] =pd.to_datetime(c.stoptime)
c['raznica'] = pd.to_datetime(c.stoptime) - pd.to_datetime(c.starttime)
# display(c.raznica[3])
c['weekend'] = pd.to_datetime(c.starttime)
# display(c.weekend.dt.dayofweek.apply(lambda x: x>4).value_counts())
c['time_of_day'] = pd.to_datetime(c.starttime).dt.hour
# display(c.time_of_day)
c['tsutok'] = c['time_of_day'].apply(lambda x: 'night' if x in (0,1,2,3,4,5,6) else 'morning' if x in (7,8,9,10,11,12) else 'day' if x in (13,14,15,16,17,18) else 'evening')
# display(c[(c['tsutok'] =='day')].value_counts())
display(f'Во сколько раз днем больше чем ночью = '+ str(int((c.tsutok.value_counts()['day']/c.tsutok.value_counts()['night']).round(0))))
# Out:
# 'Во сколько раз днем больше чем ночью = 9'

# %%
# display(melb_data['Date'])
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst = True)
# display(melb_df['Date'])
years_sold = melb_df['Date'].dt.year
# print(years_sold)
print('Min year sold:', years_sold.min())
print('Max year sold:', years_sold.max())
print('Mode year sold:', years_sold.mode()[0])
# Out:
# Min year sold: 2016
# Max year sold: 2017
# Mode year sold: 2017

# %%
melb_df['MonthSale'] = melb_df['Date'].dt.month
display((melb_df.MonthSale.value_counts(normalize=True)*100).round(1))
# Out:
# 5     14.9
# 7     14.6
# 9     13.6
# 6     13.5
# 8     11.4
# 11     8.2
# 4      7.0
# 3      5.0
# 12     4.5
# 10     4.1
# 2      3.3
# 1      0.0
# Name: MonthSale, dtype: float64

# %%
delta_days = melb_df.Date - pd.to_datetime('2016-01-01')
display(delta_days.dt.days.sort_values())
# Out:
# 6184      27
# 6183      27
# 4029      34
# 7168      34
# 4709      34
#         ...
# 13244    631
# 13243    631
# 13242    631
# 13240    631
# 13119    631
# Name: Date, Length: 13580, dtype: int64

# %%
melb_df['AgeBuilding'] = melb_df['Date'].dt.year - melb_df['YearBuilt']
display(melb_df['AgeBuilding'].sort_values())
# Out:
# 1234     -2
# 4282     -1
# 441      -1
# 3489     -1
# 7060     -1
#        ...
# 5405    166
# 5860    167
# 4843    167
# 2079    186
# 9968    821
# Name: AgeBuilding, Length: 13580, dtype: int64

# %%
melf_df = melb_df.drop('YearBuilt', axis = 1)

# %%
'''https://lms.skillfactory.ru/courses/course-v1:SkillFactory+DSPR-2.0+14JULY2021/courseware/adcad86c8b6c4e1299c49876a3024181/6ea6644c0a5a4ebbae22d0f362689baa/6?activate_block_id=block-v1%3ASkillFactory%2BDSPR-2.0%2B14JULY2021%2Btype%40vertical%2Bblock%40e756e694a15846d0bc80a1a0f42c40e6
5. Знакомимся с данными: недвижимость

Преобразуйте все столбцы, в которых меньше 150 уникальных значений, в тип данных category, исключив из преобразования столбцы Date, Rooms, Bedroom, Bathroom, Car.
В качестве ответа запишите результирующее количество столбцов, которые имеют тип данных category.'''

# %%
import pandas as pd
melb_df = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/melb_data_fe.csv', sep=',')

# display(melb_df.head())
melb_df['Date'] = pd.to_datetime(melb_df.Date)
# display(melb_df.Date.dt.quarter.value_counts())
t = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
# display(melb_df.nunique().apply(lambda x: x>150)[lambda x: x !=('Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car')].value_counts()[True])
# display(melb_df.drop(columns = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']).astype('category').nunique().apply(lambda x: x>150).value_counts()[True])
d = dict(melb_df.drop(columns = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']).nunique())
for a, x in d.items():
  if x > 150:
    melb_df[a] = melb_df[a].astype('category')
    print(a, x)
display(melb_df.info())
# display(len(list(x for x in melb_df.nunique() if x > 150)))

# display(melb_df[melb_df[['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']]].any(axis=1).nunique().apply(lambda x: x>150)[t])

# category

# %%
import pandas as pd
melb_df = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/melb_data_fe.csv', sep=',')
melb_df = melb_df.drop(columns = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'])
for i in melb_df.columns:
  if melb_df[i].nunique() <= 150:
    melb_df[i] = melb_df[i].astype('category')
display(melb_df.info())
# display(melb_df.drop(columns = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']).astype('category').nunique().apply(lambda x: x<150).value_counts()[True])
# melb_df[b].astype('category') for b in (list(a[0] for a in (dict(melb_df.drop(columns = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']).nunique()).items())))

# %%
for col in melb_df.columns: 
    if melb_df[col].nunique() < 150: 
        melb_df[col] = melb_df[col].astype('category')
display(melb_df.info())

# %%
#Сортировка by axis ascending ignore_index - новые индексы inplace 
import pandas as pd
melb_df = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/melb_data_fe.csv', sep=',')
display(melb_df.info())
# melb_df.sort_values(by='Date', ascending=False)
melb_df.sort_values(by = (['Distance', 'Price'])).loc[::10, ['Distance', 'Price']]

# %%
mask1 = melb_df['AreaRatio'] < 0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG']  == 'McGrath'
melb_df[mask1 & (melb_df['Type']=='townhouse') & mask3].sort_values(
    by=['Date', 'AreaRatio'], 
    ascending = [True, False],
    ignore_index = True
)[['Date','AreaRatio']]

# %%
filtered = melb_df[melb_df['Rooms'] > 5].copy()
filtered.sort_values(inplace=True, by=['Rooms'])
filtered.head()

# %%
# melb_df.AreaRatio.sort_values(by = 'BuildingArea', ascending = False, ignore_index = True)[1558]
melb_df.sort_values(by = ('AreaRatio'), ascending = False, ignore_index = True)['BuildingArea'][1558]
# Out:
# 126.0

# %%
'''Найдите таунхаусы (Type) с количеством жилых комнат (Rooms) больше 2. 
Отсортируйте полученную таблицу сначала по возрастанию числа комнат, 
а затем по убыванию средней площади комнат (MeanRoomsSquare). 
Индексы таблицы замените на новые. Какая цена будет у объекта в строке 18? Ответ запишите в виде целого числа.'''
melb_df[(melb_df.Type == 'townhouse') & (melb_df.Rooms > 2)].sort_values(by = ['Rooms', 'MeanRoomsSquare'], ascending = [False, True], ignore_index = True).iloc[18:19]['Price']
# Out:
# 18    1090000.0
# Name: Price, dtype: float64

# %%
'''Найдите таунхаусы (Type) с количеством жилых комнат (Rooms) больше 2. 
Отсортируйте полученную таблицу сначала по возрастанию числа комнат, 
а затем по убыванию средней площади комнат (MeanRoomsSquare). 
Индексы таблицы замените на новые. 
Какая цена будет у объекта в строке 18? Ответ запишите в виде целого числа.'''
int(melb_df[(melb_df.Type == 'townhouse') & (melb_df.Rooms > 2)].sort_values(by = ['Rooms', 'MeanRoomsSquare'], ascending = [True, False], ignore_index = True)[18:19]['Price'])
# Out:
# 1300000

# %%
mask1 = melb_df['Type'] == 'townhouse' #Эталон
mask2 = melb_df['Rooms'] > 2
int(melb_df[mask1&mask2].sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True
).loc[18, 'Price'])
# Out:
# 1300000

# %%
################################################################################### Groupby

# %%
import pandas as pd
melb_df = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/melb_data_fe.csv', sep=',')
melb_df.groupby(by = 'Type').mean()
melb_df.groupby('Type')['Price'].mean()
melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending = False)
m = melb_df

# %%
melb_df.groupby('MonthSale')['Price'].agg(['count', 'mean', 'max']).sort_values(by = 'count', ascending = False)

# %%
melb_df.groupby('MonthSale')['Price'].agg('describe')
melb_df.groupby('Regionname')['SellerG'].agg(['nunique', set])

# %%
'''Сгруппируйте данные по признаку количества комнат и найдите среднюю цену объектов недвижимости в каждой группе. 
В качестве ответа запишите количество комнат, для которых средняя цена наибольшая.'''
melb_df.groupby('Rooms')['Price'].agg(['mean', 'count', 'max']).sort_values(by = 'mean', ascending = False).nlargest(1, 'mean')
# Out:
#             mean  count        max
# Rooms
# 7      1920700.0     10  4050000.0

# %%
'''Какой регион имеет наименьшее стандартное отклонение по географической широте (Lattitude)?
В качестве ответа запишите название этого региона.'''
m = melb_df
m.head(1)
m.groupby('Regionname')['Lattitude'].std().sort_values().index[0]
# Out:
# 'Western Victoria'

# %%
'''Какая риелторская компания (SellerG) имеет наименьшую общую выручку за период с 1 мая по 1 сентября (включительно) 2017 года?
Для ответа на этот вопрос рассчитайте сумму продаж (Price) каждой компании в заданный период.
Не забудьте перевести даты в формат datetime.'''
m.head()
m['Date'] = pd.to_datetime(m['Date'])

m[(m['Date'].apply(lambda x: x > pd.to_datetime('2017-05-01') and x < pd.to_datetime('2017-09-01')))].groupby('SellerG')['Price'].sum().sort_values().index[0]    #reset_index().iloc[0]
# Out:
# 'LITTLE'

# %%
m.groupby(['Type', 'Rooms'])['BuildingArea'].median().nlargest(1)
# Out:
# Type   Rooms
# house  7        216.5
# Name: BuildingArea, dtype: float64

# %%
'''Составьте сводную таблицу, которая показывает зависимость медианной цены объекта недвижимости (Price) от риелторского агентства (SellerG) и типа здания (Type).
Во вновь созданной таблице найдите агентство, у которого медианная цена для зданий типа unit максимальна. В качестве ответа запишите название этого агентства.'''
m.groupby(['SellerG', 'Type'])['Price'].median().unstack()['unit'].nlargest(1)
# Out:
# SellerG
# Nick    900000.0
# Name: unit, dtype: float64

# %%
melb_df.pivot_table(
    values='Price',
    index=['Method','Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)

# %%
################################################################################################Pivot

# %%
melb_df.pivot_table(
    values='Price',
    index='Regionname',
    columns='Weekend',
    aggfunc='count'
)

# %%
melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)

# %%
pivot = melb_df.pivot_table(
    values = 'Landsize',
    index = 'Regionname',
    columns = 'Type',
    aggfunc = ['median', 'mean'],
    fill_value = 0
)
pivot.columns
# Out:
# MultiIndex([('median',     'house'),
#             ('median', 'townhouse'),
#             ('median',      'unit'),
#             (  'mean',     'house'),
#             (  'mean', 'townhouse'),
#             (  'mean',      'unit')],
#            names=[None, 'Type'])

# %%
display(pivot['mean']['unit'])
# Out:
# Regionname
# Eastern Metropolitan          330.444444
# Eastern Victoria              295.333333
# Northern Metropolitan         495.026538
# Northern Victoria               0.000000
# South-Eastern Metropolitan    357.864865
# Southern Metropolitan         466.380245
# Western Metropolitan          557.637232
# Western Victoria                0.000000
# Name: unit, dtype: float64

# %%
m.head()

# %%
melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
#                            median                        mean              \
# Type                        house townhouse unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230  3108.960000    0.000000
# Northern Metropolitan       459.5     134.0    0   619.249092  317.325733
# Northern Victoria           724.0       0.0    0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5     240.0  199   664.306701  212.160000
# Southern Metropolitan       586.0     246.0    0   569.643881  278.858824
# Western Metropolitan        531.0     198.0   62   507.883406  244.560669
# Western Victoria            599.5       0.0    0   655.500000    0.000000
#
#
# Type                              unit
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# Northern Victoria             0.000000
# ...

# %%
import pandas as pd
r1 = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/ratings1.csv', sep=',')
r2 = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/ratings2.csv', sep=',')
mu = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/movies.csv', sep=',')
d = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/dates.csv', sep=',')

# display(d.pd.to_datetime(date))
# years = pd.to_datetime(d["date"]).dt.years

# display(melb_data['Date'])
d['Y'] = pd.to_datetime(d['date'], dayfirst = True)
display(d.Y.dt.year.value_counts().nlargest(1))
# Out:
# 2000    10061
# Name: Y, dtype: int64

# %%
ratings = pd.concat([r1, r2])
display(ratings)
# Out:
#        userId  movieId  rating
# 0           1        1     4.0
# 1           1        3     4.0
# 2           1        6     4.0
# 3           1       47     5.0
# 4           1       50     5.0
# ...       ...      ...     ...
# 60831     610   166534     4.0
# 60832     610   168248     5.0
# 60833     610   168250     5.0
# 60834     610   168252     5.0
# 60835     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
'''6.3 Задача

В ваше распоряжение предоставлена директория users. 
В данной директории содержатся csv-файлы, в каждом из которых хранится 
информация об идентификаторах пользователей (user_id) и ссылки на их фотографии (photo_url). 
Файлов в директории может быть сколько угодно.
Вам необходимо написать функцию concat_user_files(path), параметром которой является path — путь до директории. 
Функция должна объединить информацию из предоставленных вам файлов в один DataFrame и вернуть его.
Список названий всех файлов, находящихся в директории, вы можете получить с помощью функции os.listdir(path) из модуля os. 
Отсортируйте полученный список, прежде чем производить объединение файлов.
Обратите внимание, что метод os.listdir() возвращает только названия файлов в указанной директории, а при чтении файла необходимо указывать полный путь до него.
обновить индексы после объединения.
дубликатыизбавиться.
Например, для директории users/ результирующая таблица должна иметь следующий вид:
Пример таблицы

# %%
def concat_user_files(path):
  return

# %%
import os
display(os.uname())
display(os.getcwd())
display(os.listdir(path=".") )
# Out:
# posix.uname_result(sysname='Linux', nodename='c0e685a5b85b', release='5.10.147+', version='#1 SMP Sat Dec 10 16:00:40 UTC 2022', machine='x86_64')
# '/content'
# ['.config', 'drive', 'sample_data']

# %%
import pandas as pd
melb_df = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/melb_data_fe.csv', sep=',')
print('Всего категорий с числом уникальных значений меньше 150: ',  melb_df.drop(columns = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']).nunique().apply(lambda x: x<150).value_counts()[True])
display(melb_df.nunique())
# Out:
# Всего категорий с числом уникальных значений меньше 150:  10
# Suburb              120
# Rooms                 9
# Type                  3
# Price              2204
# Method                5
# SellerG              50
# Date                 58
# Distance            202
# Postcode            198
# Bedroom              12
# Bathroom              9
# Car                  11
# Landsize           1448
# BuildingArea        602
# CouncilArea          33
# Lattitude          6503
# Longtitude         7063
# Regionname            8
# Propertycount       311
# MeanRoomsSquare    1275
# AreaRatio          6521
# MonthSale            12
# AgeBuilding         152
# WeekdaySale           7
# StreetType           11
# Weekend               2
# dtype: int64

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] 
display(melb_df.Suburb.nunique()) #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!   Suburb = 120 !!!!!!!!!!!!!!!!
max_unique_count = 150 
for col in melb_df.columns: 
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: 
        melb_df[col] = melb_df[col].astype('category')
display(melb_df.info())
# Out:
# 120
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  object
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
"""Задание 3.3
1/1 point (graded)
Создайте в таблице melb_df признак WeekdaySale (день недели). Найдите, сколько объектов недвижимости было продано в выходные (суббота и воскресенье), 
результат занесите в переменную weekend_count. В качестве ответа введите результат вывода переменной weekend_count."""

k = list(melb_df.Date.dt.dayofweek)
kk = 0
zz = 0
for x in k:
  if x >=5:
    kk +=1
  else:
   zz +=1
print(kk, zz, len(k), (kk+zz))
weekend_count = kk
display(weekend_count)
# Out:
# 12822 758 13580 13580
# 12822

# %%
"""Напишите функцию get_weekend(weekday), которая принимает на вход элемент столбца WeekdaySale и возвращает 1, если день является выходным, 
и 0 — в противном случае, и создайте столбец Weekend в таблице melb_df с помощью неё.

Примените эту функцию к столбцу и вычислите среднюю цену объекта недвижимости, проданного в выходные дни. Результат округлите до целых."""

# def get_weekend(weekday):
melb_df['WeekdaySale'] = melb_df.Date.dt.dayofweek
# display(melb_df)
# k = list(melb_df.Date.dt.dayofweek)
def get_weekend(weekday):
  if weekday >= 5:
    return 1
  else: return 0
melb_df['Weekend'] = melb_df['WeekdaySale'].apply(get_weekend)
display(int(melb_df[(melb_df.Weekend == 1)]['Price'].mean()))

melb_df['Weekend2'] = melb_df['WeekdaySale'].apply(lambda x: 1 if x >= 5 else 0)
display(int(melb_df[(melb_df['Weekend2'] == 1)]['Price'].mean()))
# Out:
# 1081198
# 1081198

# %%
from ast import Pass
from pandas.core.base import value_counts
"""Задание 4.3
Преобразуйте столбец SellerG с наименованиями риелторских компаний в таблице melb_df следующим образом: оставьте в столбце только 49 самых популярных компаний, а остальные обозначьте как 'other'.
Найдите, во сколько раз минимальная цена объектов недвижимости, проданных компанией 'Nelson', больше минимальной цены объектов, проданных компаниями, обозначенными как 'other'. Ответ округлите до десятых."""
m = melb_df.copy()
# display(m.SellerG.value_counts().nlargest(49).index)
# kkk=m.SellerG.value_counts().nlargest(49).index
# display(melb_df.SellerG.value_counts().idxmax())
# display(melb_df.SellerG.value_counts()[:49])
k = m.SellerG.value_counts()[:49]
m['SellerG2'] = m['SellerG'].apply(lambda x: x if x in k else 'other')
display(m[(m.SellerG2 == 'Nelson')]['Price'].min())
display(m[(m.SellerG2 == 'other')]['Price'].min())
display((m[(m.SellerG2 == 'Nelson')]['Price'].min()/m[(m.SellerG2 == 'other')]['Price'].min()).round(1))


a = m[m['SellerG2'] == 'Nelson']['Price'].min() 
b = m[m['SellerG2'] == 'other']['Price'].min() 
print(round(a/b, 1))
# Out:
# 170000.0
# 131000.0
# 1.3
# 1.3

# %%
Skillfactory | Задача по Python
Представьте, что вы занимаетесь подготовкой данных о вакансиях с платформы hh.ru. В вашем распоряжении имеется таблица, в которой с помощью парсинга собраны резюме кандидатов. 
В этой таблице есть текстовый столбец «Опыт работы». Пример такого столбца представлен ниже в виде объекта Series. Структура текста в столбце фиксирована и не может измениться.
Напишите функцию get_experience(arg), аргументом которой является строка столбца с опытом работы. Функция должна возвращать опыт работы в месяцах. Не забудьте привести результат к целому числу.
Примечание. Обратите внимание, что опыт работы может выражаться только в годах или только в месяцах. Учтите это при построении своей функции.
При проверке мы будем применять вашу функцию к разным Series с помощью метода apply().
Пример результата работы функции get_experience:
Исходный датафрейм → Результат

# %%
from pandas.core import series
def get_experience(arg):
  return((int(arg.split()[3])*12)+int(arg.split()[5]))

s = pd.Series(['0	Опыт работы 8 лет 3 месяца', '1	Опыт работы 3 года 5 месяцев'])
display(s.apply(get_experience))
# Out:
# 0    99
# 1    41
# dtype: int64

# %%
import pandas as pd
test_series_1 = pd.Series([
    'Опыт работы 8 лет 3 месяца',
    'Опыт работы 3 года 5 месяцев',
    'Опыт работы 1 год 9 месяцев',
    'Опыт работы 3 месяца',
    'Опыт работы 6 лет'
])

test_series_2 = pd.Series([
    'Опыт работы 5 лет',
    'Опыт работы 5 месяцев',
    'Опыт работы 1 год 1 месяц',
    'Опыт работы 3 месяца',
    'Опыт работы 7 лет'
])


def get_experience(arg):
  if arg.split()[3] in ('лет', 'года', 'год') and len(arg.split()) >= 5:
    return((int(arg.split()[2])*12)+int(arg.split()[4])) 
  if arg.split()[3] in ('месяца', 'месяц'):
    return (int(arg.split()[2]))
  elif arg.split()[3] in ('лет', 'год', 'года'):
    return (int(arg.split()[2])*12)
  else: return 'lskdjfksdjfksdj'

print(test_series_1.apply(get_experience))
# Out:
# 0    99
# 1    41
# 2    21
# 3     3
# 4    72
# dtype: int64

# %%
# задание
import pandas as pd
test_series_1 = pd.Series([
    'Опыт работы 8 лет 3 месяца',
    'Опыт работы 3 года 5 месяцев',
    'Опыт работы 1 год 9 месяцев',
    'Опыт работы 3 месяца',
    'Опыт работы 6 лет'
])

def get_experience(arg):
  if arg.split()[3] in ('лет', 'года', 'год') and len(arg.split()) >= 5:
    return((int(arg.split()[2])*12)+int(arg.split()[4])) 
  if arg.split()[3] in ('месяца', 'месяц', 'месяцев'):
    return (int(arg.split()[2]))
  elif arg.split()[3] in ('лет', 'год', 'года'):
    return (int(arg.split()[2])*12)
  else: return 'lskdjfksdjfksdj'

print(test_series_1.apply(get_experience))
# Out:
# 0    99
# 1    41
# 2    21
# 3     3
# 4    72
# dtype: int64

# %%
import pandas as pd
ufo = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/ufo.csv')
ufo['Date'] = pd.to_datetime(ufo['Time'], dayfirst = True)
ufo['years'] = ufo.Date.dt.year
display(ufo.years.value_counts())
# melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst = True)
# # display(melb_df['Date'])
# years_sold = melb_df['Date'].dt.year
# Out:
# 1999    2774
# 2000    2635
# 1998    1743
# 1995    1344
# 1997    1237
#         ...
# 1936       2
# 1930       2
# 1935       1
# 1934       1
# 1933       1
# Name: years, Length: 68, dtype: int64

# %%
import pandas as pd
ufo = pd.read_csv('https://raw.githubusercontent.com/kuchsk/PY/main/ufo.csv')
ufo['Date'] = pd.to_datetime(ufo['Time'])
ufon = ufo[ufo.State == 'NV'].sort_values(by='Date')

display(ufon)
display(ufon['Date'].diff().mean())
# Out:
#              City Colors Reported Shape Reported State              Time  \
# 76      Las Vegas             NaN           DISK    NV   7/15/1947 10:00
# 172    Nellis AFB             NaN           DISK    NV   2/17/1952 18:00
# 565        Fallon             NaN           OVAL    NV    9/15/1959 0:00
# 566     Goldfield             NaN          LIGHT    NV    9/15/1959 1:00
# 613           NaN             NaN           DISK    NV    7/1/1960 12:00
# ...           ...             ...            ...   ...               ...
# 17447    Laughlin             NaN      FORMATION    NV   9/16/2000 22:00
# 17567   Las Vegas             NaN         SPHERE    NV   9/30/2000 22:25
# 17617   Las Vegas      RED YELLOW          OTHER    NV   10/6/2000 20:25
# 17890        Reno             NaN       TRIANGLE    NV    11/7/2000 2:15
# 18104   Las Vegas             NaN       TRIANGLE    NV  12/10/2000 17:30
#
#                      Date
# 76    1947-07-15 10:00:00
# 172   1952-02-17 18:00:00
# ...

# %%
import pandas as pd
ufo = pd.read_csv('https://raw.githubusercontent.com/kuchsk/PY/main/ufo.csv')
ufo['Date'] = pd.to_datetime(ufo['Time'])
display(ufo[ufo.State == 'NV']['Date'].diff().mean())
# Out:
# Timedelta('68 days 22:19:49.399293286')

# %%
import pandas as pd
ufo = pd.read_csv('https://raw.githubusercontent.com/kuchsk/PY/main/ufo.csv')
ufo['Date'] = pd.to_datetime(ufo['Time'])
display(ufo[ufo.State == 'NV']['Date'].diff().mean())
# Out:
# Timedelta('68 days 22:19:49.399293286')

# %%
# задача https://lms.skillfactory.ru/courses/course-v1:SkillFactory+DSPR-2.0+14JULY2021/courseware/adcad86c8b6c4e1299c49876a3024181/896fdb5831654c3bb6ca5590f2079ba4/?child=first

# Напишите функцию delete_columns(df, col=[]), которая удаляет столбцы из DataFrame и возвращает новую таблицу. 
# Если одного из указанных столбцов не существует в таблице, то функция должна возвращать None.

customer_df = pd.DataFrame({
            'number': [0, 1, 2, 3, 4],
            'cust_id': [128, 1201, 9832, 4392, 7472],
            'cust_age': [13, 21, 19, 21, 60],
            'cust_sale': [0, 0, 0.2, 0.15, 0.3],
            'cust_year_birth': [2008, 2000, 2002, 2000, 1961],
            'cust_order': [1400, 14142, 900, 1240, 8430]
        })


def delete_columns(df, col=[]):
  try:
    return df.drop(col, axis = 1)
  except: return None
display(delete_columns(customer_df, col = ['number', 'cust_age']))
# Out:
#    cust_id  cust_sale  cust_year_birth  cust_order
# 0      128       0.00             2008        1400
# 1     1201       0.00             2000       14142
# 2     9832       0.20             2002         900
# 3     4392       0.15             2000        1240
# 4     7472       0.30             1961        8430

# %%
'''Задание 2.4
Задан DataFrame countries_df, содержащий следующие столбцы: название страны, население (population) в миллионах человек и площадь страны (square) в квадратных километрах.

Для каждой страны рассчитайте плотность населения (количество человек на квадратный километр). Плотность населения рассчитывается как количество человек, проживающих на территории отдельной страны, делённое на площадь этой страны. 

Затем по полученным данным рассчитайте среднее по плотностям населения в указанных странах. Ответ округлите до сотых.


'''
import pandas as pd
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

display(countries_df)
countries_df['plotnost'] = (countries_df.population*1000000/countries_df.square).round(2)
print(f'среднее по плотностям населения в указанных странах: ', countries_df.plotnost.mean().round(2))
# Out:
#      country  population    square
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902
# среднее по плотностям населения в указанных странах:  84.93

# %%
display(m.head(2))
m['Date'] = pd.to_datetime(m['Date'], dayfirst= True)
# display(m.head())

y = m.Date.dt.year
m['mes'] = m.Date.dt.month
display((m.mes.value_counts(normalize = True)*100).round(1))

delta_days=(m.Date - pd.to_datetime('2016-01-01'))
display(delta_days.dt.days)
m['Big'] = m.Landsize.apply(lambda x: 'Big' if x > 200 else False)
display(m.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5c2edcfe0d2d> in <module>
# ----> 1 display(m.head(2))
#       2 m['Date'] = pd.to_datetime(m['Date'], dayfirst= True)
#       3 # display(m.head())
#       4
#       5 y = m.Date.dt.year
#
# NameError: name 'm' is not defined

# %%
display(melb_df['Date'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0f6eeb3ee256> in <module>
# ----> 1 display(melb_df['Date'])
#
# NameError: name 'melb_df' is not defined

# %%
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Это istories

# %%
import pandas as pd
h = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/istories/IHME.csv')
h.head()
h.shape
h1 = h.iloc[:150000,:]
h2 = h.iloc[150000:,:]
h3 = pd.concat([h1, h2], axis = 0)
h3.shape
h['valRound']=h.val.round(decimals = 1)
h.head()
# Out:
#   measure location     sex       age                           cause metric  \
# 0  Deaths    Samoa    Male  All Ages    Chronic respiratory diseases   Rate
# 1  Deaths    Samoa  Female  All Ages    Chronic respiratory diseases   Rate
# 2  Deaths    Samoa    Both  All Ages    Chronic respiratory diseases   Rate
# 3  Deaths    Samoa    Male  All Ages  Skin and subcutaneous diseases   Rate
# 4  Deaths    Samoa  Female  All Ages  Skin and subcutaneous diseases   Rate
#
#    year        val      upper      lower  valRound
# 0  2000  64.470214  81.808307  53.476793      64.5
# 1  2000  55.234399  77.883497  39.978647      55.2
# 2  2000  60.039961  76.013089  49.941986      60.0
# 3  2000   2.246741   3.467454   1.438979       2.2
# 4  2000   1.368385   1.945448   0.866099       1.4

# %% [markdown]
# Задание 6.3 (Внешний источник)
#
# директория users.
# В  директории csv-файлы, в каждом user_id и photo_url
#
# написать функцию concat_user_files(path) path — путь до директории. объединить информацию из файлов в один DataFrame и вернуть его
#
# Список названий всех файлов os.listdir(path) из модуля os.
# Отсортируйте список, прежде чем производить объединение файлов.
#
# метод os.listdir() возвращает только названия файлов в указанной директории, а при чтении файла необходимо указывать полный путь до него.
#
# обновить индексы результирующей таблицы после объединения.
#
# дубликаты избавиться

# %%
import pandas as pd
import os

def concat_users_files(path):
  return pd.concat((pd.read_csv(path+f) for f in sorted(os.listdir(path))), ignore_index=True).drop_duplicates()
  
print(concat_users_files('/content/drive/Shareddrives/kuchsk@gmail.com/py/7/'))

# %%
'''7.5 Skillfactory | Задача по Python

item_id — идентификатор модели;
vendor — производитель модели;
stock_count — имеющееся на складе количество данных моделей (в штуках);
purchase_id — идентификатор покупки;
price — стоимость модели в покупке.
Вам необходимо сделать следующее:

Сформируйте DataFrame merged, так чтобы после объединения purchase_df и items_df остались модели, которые учтены на складе и имели продажи.

На основе таблицы merged найдите суммарную выручку, которую можно было бы получить от продажи всех товаров, имеющихся на складе. 
Результат занесите в переменную income.

# %%
import pandas as pd
items_df = pd.DataFrame({
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394],
    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],
    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]
})

purchase_df = pd.DataFrame({
    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132],
    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]
})

DataFrame_merged = items_df.merge(purchase_df, on = 'item_id', how = 'inner')
# movies.set_index('movieId'),
#     on='movieId',
#     how='left'
# display(DataFrame_merged)

# %%
merged = items_df.merge(purchase_df, on = 'item_id')
income = (merged.stock_count*merged.price).sum()
display(income)
# Out:
# 19729490

# %%
#эталон
import re
import pandas as pd
def get_year_release(arg):
  condidates = re.findall(r'\(\d{4}\)', arg)
  if len(condidates) > 0:
    year = condidates[0].replace('(', '')
    year = year.relpace(')', '')
    return int(year)
  else: return None
display(get_year_release('/content/drive/Shareddrives/kuchsk@gmail.com/py/ratings_movies.csv'))

# def ff(arg):
#   fff = arg[arg.title.str.contains('19' or '20' or '21' or '22')]
#   print(arg.shape[0]- fff.shape[0])
# print(ff(c))
# Out:
# None

# %% [markdown]
# Подсказка (1 из 4): Произведите фильтрацию по условию «год выпуска».
# Подсказка (2 из 4): На отфильтрованной таблице произведите группировку по названию фильма(title) и посчитайте среднее по столбцу rating для каждого фильма.

# %%
import re 
import pandas as pd
c = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/ratings_movies.csv')

def aa(arg):
  y = []
  n = []
  d = {}
  for i in arg.title:
    aa = re.findall(r'\(\d\d\d\d\)', i)
    aaa = re.findall(r'\d\d\d\d', str(aa))
    if len(aaa):
      y.append(aaa[0])
      n.append(i)

  arg = c.merge(pd.DataFrame({'Year':y, 'title' : n}), on = 'title')
  return f'Фильмов без года в названии: {len(c.title)-len(y)})' , (f'Самый низкий рейтинг у фильма 1999 года: '), arg[arg.Year == '1999'].groupby(by = 'title')['rating'].mean().nsmallest(1)
  return arg[arg.Year == '2010'].groupby(by = 'genres')['rating'].mean().nsmallest(1)
  
display(aa(c))
# Out:
# ('Фильмов без года в названии: 18)',
#  'Самый низкий рейтинг у фильма 1999 года: ',
#  title
#  Bloodsport: The Dark Kumite (1999)    0.5
#  Name: rating, dtype: float64)

# %%
Какой пользователь (userId) посмотрел наибольшее количество различных (уникальных) комбинаций жанров (genres) фильмов? 
В качестве ответа запишите идентификатор этого пользователя.

# %%
print(c[['userId', 'genres']].groupby('userId').agg('nunique').nlargest(1, 'genres'))
# Out:
#         genres
# userId
# 599        524

# %%
Найдите пользователя, который выставил наименьшее количество оценок, но его средняя оценка фильмам наибольшая.
В качестве ответа укажите идентификатор этого пользователя.
Чтобы рассчитать несколько параметров для каждого пользователя (количество оценок и среднюю оценку), можно воспользоваться методом agg() на сгруппированных данных.

# %%
c[['userId', 'rating']].groupby(by = 'userId').mean().nlargest(1, 'rating')
# Out:
#         rating
# userId
# 53         5.0

# %%
Найдите сочетание жанров (genres) за 2018 году, которое имеет наибольший средний рейтинг (среднее по столбцу rating), 
и при этом число выставленных ему оценок (количество значений в столбце rating) больше 10.
Запишите сочетание так же, как оно указано в таблице (через разделитель |, без пробелов).

# %%
import re 
import pandas as pd
c = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/ratings_movies.csv')
pd.DataFrame((pd.DataFrame((c[c['title'].str.contains(r'\(2018') & (c.rating)])['genres'].value_counts())).genres.nlargest(1))
# Out:
#                          genres
# Action|Adventure|Sci-Fi      14

# %%
c[c.title.str.contains('\(2018')].groupby('genres')['rating'].agg(['mean', 'count']).nlargest(1,'count') #!!!!!!!!!! хорошее
# Out:
#                              mean  count
# genres
# Action|Adventure|Sci-Fi  3.928571     14

# %%
Добавьте в таблицу новый признак year_rating — год выставления оценки. 
Создайте сводную таблицу, которая иллюстрирует зависимость среднего рейтинга фильма от года выставления оценки и жанра. 
Выберите верные варианты ответа, исходя из построенной таблицы:

A За весь период (с 1996 по 2018 год) сочетание жанров Action|Adventure ни разу не получало среднюю оценку ниже 3.
B Наилучшую оценку жанр Action|Adventure|Animation|Children|Comedy|IMAX получил в 2010 году.
C Среди сочетаний жанров, получивших наивысшую среднюю оценку в 2018 году, есть сочетание Animation|Children|Mystery.
D Для жанра Comedy прослеживается тенденция падения рейтинга с каждым годом (с 1996 по 2018).

# %%
from datetime import datetime
c['year_rating'] = (pd.to_datetime(c.date)).dt.year
ccc = (c[c.year_rating.isin(range(1996, 2019))].groupby(['genres','year_rating'])['rating'].mean())
c4 = pd.DataFrame(ccc)
c5 = pd.DataFrame(c4.rating)
c6 = c.pivot_table(
    index = 'year_rating',
    columns = 'genres',
    values = 'rating',
    aggfunc = 'mean'
 )
c6

# %%
#эталон
joined = c
joined['date'] = pd.to_datetime(joined['date'])
joined['year_rating'] = joined['date'].dt.year
pivot = joined.pivot_table(
    index='year_rating',
    columns='genres',
    values='rating',
    aggfunc='mean'
)
display(pivot)

# %%
Объедините заданные таблицы в таблицу orders_products, 
чтобы в результирующей таблице оказалась информация обо всех заказах, 
но не оказалось информации о продуктах, на которых заказов ещё не поступало

# %%
import pandas as pd
o = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/orders.csv', sep = ';')
p = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/products.csv', error_bad_lines=False, sep = ';')
o.rename(columns = {'ID товара':'Product_ID'}, inplace = True)
# display(o)
# display(p)
# op = merge.o(p, on = 'Product_ID')
op = pd.merge(p, o, on = 'Product_ID', how = 'inner')
# op.groupby(['ID Покупателя'])['Price', 'Количество'].sum()
op
o
# Какой идентификатор (Order ID) имеет заказ, для которого не оказалось информации о товаре?
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# ...

# %%
import pandas as pd
o = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/orders.csv', sep = ';')
p = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/products.csv', error_bad_lines=False, sep = ';')
op = pd.merge(o, p, left_on= 'ID товара', right_on = 'Product_ID', how = 'left')
op[op.Name.isna()]
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           Дата создания  Order ID  ID Покупателя  \
# 17  01.01.2001 00:00:00         0              1
#
#                              Статус Оплачен Отменен Отгружен  ID товара  \
# 17  Оплачен, формируется к отправке      Да     Нет      Нет        666
#
#     Количество  Product_ID Name  Price CURRENCY
# 17           1         NaN  NaN    NaN      NaN

# %%
help(pd.DataFrame.merge)

# %% [markdown]
# Курс Профессия Data Science Модуль 12 “Продвинутые методы работы с данными в Pandas”
#
# df.sort_values(by='col', ascending=True)
# df.sort_values(by='col', ascending=False)
# df.sort_values(by=['col1', 'col2', ascending=[False, True]])
# df.groupby(by='group_col')['col'].mean()
# df.groupby(by='group_col')['col'].agg(['mean', 'median', 'count')
#
# mean Среднее
# median Медиана
# std Стандартное отклонение
# min Минимум
# max Максимум
# sum Сумма
#
# melb_df.groupby(by=['group_col1', 'group_col2'])['col'].mean().unstack()
# melb_df.pivot_table(values='target_col', index='col1', columns='col2',aggfunc='mean', fill_value=0)
# melb_df.pivot_table(values='target_col',index=['idx1', 'idx2', ..., 'idxn']
# columns=['col1', 'col2’, ..., 'coln'],aggfunc='mean',fill_value=0)
# pd.concat([table1, table2, ..., tablen],ignore_index=True,axis=0)
#
#
# pd.concat([table1, table2, ..., tablen],ignore_index=True,axis=1)
#
# ТИП ОБЪЕДИНЕНИЯ АНАЛОГИЯ ИЗ ТЕОРИИ МНОЖЕСТВ МАТЕМАТИЧЕСКОЕ ОБОЗНАЧЕНИЕ
#
# inner (внутреннее) Пересечение (intersection)
# множеств А и В А ∩ 𝐵 outer (внешнее)
#
# full Объединение (union)множеств А и В А 𝖴 𝐵 left
#
# Вычитание (difference) множества B из результата объединения (union) множеств А и В (А 𝖴 𝐵) − 𝐵 right
#
# Вычитание (difference) множества А из результата объединения (union) множеств А и В (А 𝖴 В) − А
#
# ОБЪЕДИНЕНИЕ ТАБЛИЦ ПО ИНДЕКСУ:JOIN()
#
#
# l_table.join(r_table,how='outer')
# l_table.join(r_table.set_index('key_col'),on='key_col',how='inner')
#
# l_table.merge(r_table,right_index=True,left_index=True,how='inner')
# l_table.merge(r_table,on='key_col',how='inner')

# %%
Эталонные решения

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'])
quarters = melb_df['Date'].dt.quarter
print(quarters.value_counts().iloc[1])

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] 
max_unique_count = 150 
for col in melb_df.columns: 
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: 
        melb_df[col] = melb_df[col].astype('category')
display(melb_df.info())

# %%
int(melb_df.sort_values(
    by='AreaRatio', 
    ignore_index=True,
    ascending=False
).loc[1558, 'BuildingArea'])

# %%
mask1 = melb_df['Type'] == 'townhouse'
mask2 = melb_df['Rooms'] > 2
int(melb_df[mask1&mask2].sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True
).loc[18, 'Price'])

# %%
melb_df.groupby('Rooms')['Price'].mean().sort_values(ascending=False)

# %%
melb_df.groupby('Regionname')['Lattitude'].std().sort_values()

# %%
date1 = pd.to_datetime('2017-05-01')
date2 = pd.to_datetime('2017-09-01')
mask = (date1 <= melb_df['Date']) & (melb_df['Date']<= date2)
melb_df[mask].groupby('SellerG')['Price'].sum().sort_values(ascending=True)

# %%
pivot = melb_df.pivot_table(
    values='BuildingArea',
    index='Type',
    columns='Rooms',
    aggfunc='median',
    fill_value=0
)
display(pivot)

# %%
pivot = melb_df.pivot_table(
    values='Price',
    index='SellerG',
    columns='Type',
    aggfunc='median',
)
max_unit_price = pivot['unit'].max()
print(pivot[pivot['unit'] == max_unit_price].index[0])

# %%
def concat_users_files(path):
    data = pd.DataFrame()
    file_names = os.listdir(path)
    file_names.sort()
    for file in file_names:
        tmp_data = pd.read_csv(path + '/' + file)
        data = pd.concat([data, tmp_data], axis=0, ignore_index=True)
    data = data.drop_duplicates()
    return data

# %%
merged = items_df.merge(purchase_df, how='inner', on='item_id')
income = (merged['price'] * merged['stock_count']).sum()

# %%
joined['year_release'] = joined['title'].apply(get_year_release)
joined.info()

# %%
mask = joined['year_release'] == 1999
joined[mask].groupby('title')['rating'].mean().sort_values()

# %%
mask = joined['year_release'] == 2010
joined[mask].groupby('genres')['rating'].mean().sort_values()

# %%
joined.groupby('userId')['genres'].nunique().sort_values(ascending=False)

# %%
joined.groupby('userId')['rating'].agg(
    ['count', 'mean']
).sort_values(['count', 'mean'], ascending=[True, False])

# %%
mask = joined['year_release'] == 2018
grouped = joined[mask].groupby('genres')['rating'].agg(
    ['mean', 'count']
)
grouped[grouped['count']>10].sort_values(
    by='mean',
    ascending=False
)

# %%
joined['date'] = pd.to_datetime(joined['date'])
joined['year_rating'] = joined['date'].dt.year
pivot = joined.pivot_table(
    index='year_rating',
    columns='genres',
    values='rating',
    aggfunc='mean'
)
display(pivot)

# %%
orders_products = orders_df.merge(
    product_df, 
    left_on='ID товара',
    right_on='Product_ID',
    how='left')
orders_products[orders_products['Name'].isna()]

# %%
orders_products[orders_products['Отменен'] == 'Да']['Name']

# %%
orders_products['Profit'] = orders_products['Price'] * orders_products['Количество'] 
orders_products[orders_products['Оплачен'] == 'Да'].groupby('ID Покупателя')['Profit'].sum().sort_values(ascending=False)

# %%
# Графики# Графики# Графики# Графики# Графики# Графики# Графики# Графики# Графики# Графики# Графики# Графики# Графики# Графики# Графики

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
v = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/vgsales.csv')
vg_data = v
display(v.head())
dinamic_by_region = vg_data[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Year_of_Release']].groupby('Year_of_Release').sum()
display(dinamic_by_region.head())
fig = plt.figure(figsize=(12, 6))
lineplot = sns.lineplot(data=dinamic_by_region)

# lineplot.set_title('Динамика продаж видеоигр', fontsize=16)
# lineplot.set_xlabel('Год выпуска')
# lineplot.set_ylabel('Суммарный объём продаж')
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
# На практике, в Data Science такие графики чаще всего используются для визуализации временных рядов, 
# например чтобы отследить динамику продаж во времени, число активных пользователей по дням, изменение курса валют и акций.

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
v = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/vgsales.csv')
v2 = v[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Year_of_Release']].groupby('Year_of_Release').sum()
# plt.figure(figsize=(12, 6))
# display(sns.lineplot(data = v))
display(sns.lineplot(data = v2))
# Out:
# <AxesSubplot:xlabel='Year_of_Release'>

# %%
# Гистограммы часто используются для оценки распределения числового признака, например мы можем понять, 
# как распределены цены на товары, число шагов, масса метеоритов, падающих на землю.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

melb_data = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/melb_data.csv')

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 10))
# plt.subplots_adjust(hspace=.0)
sns.histplot(data=melb_data, x='Price', bins=30, ax=axes[0])
sns.histplot(data=melb_data, x='Price', y='Type',bins=30, color='green', ax=axes[1])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Type'>

# %%
# Диаграммы рассеяния являются стандартным средством визуализации связи между двумя числовыми переменными. 
# Однако через настройки графика в исследование зависимости можно добавить и несколько категориальных переменных.

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

penguins_df = sns.load_dataset("penguins")          #откуда данные?
fig = plt.figure(figsize=(10, 5))

scatterplot = sns.scatterplot(data=penguins_df, x='bill_length_mm', y='flipper_length_mm', hue='species', s=100, size='sex', sizes=(50, 300))
scatterplot.set_title('Взаимосвязь размеров параметров тела разных видов пингвинов', fontsize=16)
scatterplot.set_xlabel('Длина клюва')
scatterplot.set_ylabel('Длина крыльев')
# Out:
# Text(0, 0.5, 'Длина крыльев')

# %%
# Круговые диаграммы наглядны, когда нужно показать, как делится на части что-либо целое
import matplotlib.pyplot as plt
import pandas as pd

game_of_thrones_df = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/character-deaths.csv')
# game_of_thrones_df['Allegiances'] = game_of_thrones_df['Allegiances'].str.replace('House ', '')
fig = plt.figure(figsize=(12, 6))
ax = fig.add_axes((1, 1, 1, 1))
deaths_count = game_of_thrones_df['Allegiances'].value_counts().sort_values(ascending=False).head(7)
pie = ax.pie(deaths_count, labels=deaths_count.index, autopct='%1.1f%%', startangle=90)
title = ax.set_title('Смертность персонажей в GoT в зависимости от их верности', fontsize=16)
plt.show(pie)

# %%
# применение столбчатых диаграмм в Data Science — сравнение категорий друг с другом. 
# Например, сравнение ресторанов по суммарной прибыли, сравнение средних расходов пользователей, сравнение медианной стоимости квартир по районам и т. д.# Преимущество столбчатых диаграмм над круговыми в том, 
# что в столбчатые диаграммы можно добавлять разделение по другим категориальным 
# признакам и рассматривать совместное распределение показателей, 
# тем самым повышая информативность. Такие диаграммы называются многоуровневыми.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

amazon_data = pd.read_csv('/content/drive/Shareddrives/kuchsk@gmail.com/py/amazon_com.csv')

def replace_url(brand_name):
    if 'ref=' in brand_name:
        if 'Calvin' in brand_name:
            return 'Calvin-Klein'
        elif 'Wacoal' in brand_name:
            return 'Wacoal'
        else:
            return 'b.tempt'
    else:
        return brand_name
    
amazon_data['brand_name'] = amazon_data['brand_name'].apply(replace_url)
amazon_data['price'] = amazon_data['price'].str.replace('$', '').astype('float64')
amazon_data['brand_name'].unique()
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 7))
barplot1 = sns.barplot(data=amazon_data, x='brand_name', y='price', orient='v', ax = axes[0], ci=None)

barplot1.tick_params(axis='x', rotation=70);
barplot1.set_title('Средняя стоимость товаров по брендам', fontsize=16);
barplot1.set_xlabel('Название бренда', fontsize=14);
barplot1.set_ylabel('Средняя цена', fontsize=14);
barplot1.grid()

barplot2 = sns.barplot(data=amazon_data, x='brand_name', y='price', hue='product_category', orient='v', ax = axes[1], ci=None, dodge=False)
barplot2.tick_params(axis='x', rotation=70);
barplot2.set_title('Средняя стоимость товаров по брендам и категориям', fontsize=16);
barplot2.set_xlabel('Название бренда', fontsize=14);
barplot2.set_ylabel('Средняя цена', fontsize=14);
barplot2.grid()
# Out:
# <ipython-input-54-571ee00e32a1>:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   amazon_data['price'] = amazon_data['price'].str.replace('$', '').astype('float64')

# %%
# Тепловая карта — это графическое представление некоторой таблицы, 
# где значения в ячейках выделяются определённым цветом или интенсивностью цвета.

tweets_df = pd.read_csv("https://bit.ly/3cngqgL", 
                 parse_dates=['date_utc'], 
                 dtype={'hour_utc':int,'minute_utc':int,'id':str}
                )#/content/drive/Shareddrives/kuchsk@gmail.com/py/biden_trump_tweets.csv
g = tweets_df.groupby(['hour_utc','minute_utc','username'])
tweet_cnt = g.id.nunique()
jb_tweet_cnt = tweet_cnt.loc[:,:,'JoeBiden'].reset_index().pivot_table(index='hour_utc', columns='minute_utc', values='id', fill_value=0)
dt_tweet_cnt = tweet_cnt.loc[:,:,'realDonaldTrump'].reset_index().pivot_table(index='hour_utc', columns='minute_utc', values='id', fill_value=0)
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(16, 12))
jb_heatmap = sns.heatmap(jb_tweet_cnt, linewidth=1, linecolor='w', cmap='viridis', ax = axes[0])
jb_heatmap.set_title('@JoeBiden');
jb_heatmap.set_xlabel('Минута часа');
jb_heatmap.set_ylabel('Час дня');

dt_heatmap = sns.heatmap(dt_tweet_cnt, linewidth=1, linecolor='w', cmap='viridis', ax = axes[1])

dt_heatmap.set_title('@realDonaldTrump');
dt_heatmap.set_xlabel('Минута часа');
dt_heatmap.set_ylabel('Час дня');

# %%
# КОРОБЧАТАЯ ДИАГРАММА (BOXPLOT, BOX AND WHISKER PLOT)
# Синонимичные названия диаграммы — ящик с усами и диаграмма размаха.
# Коробчатые диаграммы, которые были введены в употребление Джоном Тьюки в 1977 году, 
# являются новым типом диаграмм для исследования распределения числового признака по отношению к предыдущим. 
# Диаграмма основана на понятии квантилей.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

citibike_df = pd.read_csv('data/citibike-tripdata.csv')
citibike_df['age'] = 2018 - citibike_df['birth year']

fig = plt.figure(figsize=(12, 6))
boxplot = sns.boxplot(data=citibike_df, x='age', y='usertype')
boxplot.set_title('Boxplot для возраста пользователей приложения CitiBike', fontsize=16)
boxplot.set_xlabel('Возраст пользователя')
boxplot.set_ylabel('Тип пользователя')

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
import numpy as np
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %%
# 4/13  3. Знакомимся с новыми данными: коронавирус

# %%
import pandas as pd
vaccinations_data = pd.read_csv('https://raw.githubusercontent.com/kuchsk/PY/main/country_vaccinations.csv')
covid_data = pd.read_csv('https://raw.githubusercontent.com/kuchsk/PY/main/covid_data.csv')

vaccinations_data = vaccinations_data[
    ['country', 'date', 'total_vaccinations', 
     'people_vaccinated', 'people_vaccinated_per_hundred',
     'people_fully_vaccinated', 'people_fully_vaccinated_per_hundred',
     'daily_vaccinations', 'vaccines']
]

covid_data = covid_data.groupby(
    ['date', 'country'],
    as_index = False
)[['confirmed', 'deaths', 'recovered']].sum()
covid_data['date'] = pd.to_datetime(covid_data['date'])
covid_data['active'] = covid_data['confirmed'] - covid_data['deaths'] - covid_data['recovered']
covid_data = covid_data.sort_values(by = ['country', 'date'])
covid_data['daily_confirmed'] = covid_data.groupby('country')['confirmed'].diff()
covid_data['daily_recovered'] = covid_data.groupby('country')['deaths'].diff()

vaccinations_data['date'] = pd.to_datetime(vaccinations_data['date'])

# С помощью метода merge() объедините таблицы covid_data и vaccinations_data по столбцам date и country.
# Тип объединения выставьте так, чтобы в результирующую таблицу попали только наблюдения за период, вычисленный в задании 3.1. 
# То есть в результирующую таблицу должны попасть все записи из таблицы covid_data и из её пересечения с vaccinations_data, но не более. 
# Результат объединения занесите в переменную covid_df.

covid_df = pd.merge(covid_data, vaccinations_data, on = ['date', 'country'], how = 'left')
covid_df.head(3)
# Out:
#         date      country  confirmed  deaths  recovered  active  \
# 0 2020-02-24  Afghanistan        1.0     0.0        0.0     1.0
# 1 2020-02-25  Afghanistan        1.0     0.0        0.0     1.0
# 2 2020-02-26  Afghanistan        1.0     0.0        0.0     1.0
#
#    daily_confirmed  daily_recovered  total_vaccinations  people_vaccinated  \
# 0              NaN              NaN                 NaN                NaN
# 1              0.0              0.0                 NaN                NaN
# 2              0.0              0.0                 NaN                NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations vaccines
# 0                                  NaN                 NaN      NaN
# ...

# %%
# #В получившейся в задании 3.3 таблице covid_df создайте признаки death_rate  — общий процент смертей среди зафиксированных случаев (летальность) 
# и recover_rate — общий процент случаев выздоровления. 
# Данные характеристики рассчитайте как отношение числа смертей (deaths) 
# и числа выздоровлений (recovered) к числу зафиксированных случаев (confirmed) 
# и умножьте результаты на 100%.

# %%
covid_df['death_rate'] = covid_df.deaths / covid_df.confirmed * 100
covid_df['recover_rate'] = covid_df.recovered / covid_df.confirmed * 100

dusa = (covid_df[(covid_df.country == 'United States') & ((covid_df.deaths > 0) | (covid_df.recovered > 0))][['country', 'confirmed', 'deaths', 'recovered', 'active', 'death_rate', 'recover_rate']])
dusa.death_rate.nlargest(1).round(2)
# Out:
# 82584    7.19
# Name: death_rate, dtype: float64

# %%
# Чему равен средний процент выздоровевших в России (Russia)? Ответ округлите до второго знака после запятой.
druss = (covid_df[(covid_df.country == 'Russia')][['country', 'confirmed', 'deaths', 'recovered', 'active', 'death_rate', 'recover_rate']])
druss.recover_rate.mean().round(2)
# Out:
# 67.06

# %%
covid_df
grouped_cases = covid_df.groupby('date')['daily_confirmed'].sum()
grouped_cases.plot(kind = 'line', figsize = (12, 4), title = 'Ежедневная заболеваемость по странам', grid = True, lw = 3)
# Out:
# <AxesSubplot:title={'center':'Ежедневная заболеваемость по странам'}, xlabel='date'>

# %%
covid_df
g = covid_df.groupby('date')['daily_confirmed'].sum()
g.plot(kind = 'line', figsize= (12, 4), grid = True, lw = 1)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
grouped_cases = covid_df.groupby('date')['daily_confirmed'].sum()
grouped_cases.plot(
    kind = 'hist',
    figsize = (10, 6),
    title = 'Распределение ежедневной заболеваемости', 
    grid = True,
    color = 'black',
    bins = 10
)
# Out:
# <AxesSubplot:title={'center':'Распределение ежедневной заболеваемости'}, ylabel='Frequency'>

# %%
grouped_country = covid_df.groupby(['country'])['confirmed'].last()
grouped_country = grouped_country.nlargest(10)
grouped_country.plot(
    kind = 'bar',
    grid = True,
    figsize = (12,4),
    colormap='plasma'
)
# Out:
# <AxesSubplot:xlabel='country'>

# %%
grouped_country = covid_df.groupby(['country'])[['confirmed', 'deaths']].last()
grouped_country = grouped_country.nlargest(10, columns = ['confirmed'])
display(grouped_country)
grouped_country.plot(
    kind = 'bar',
    grid = True,
    figsize=(12,4)
)
# Out:
#                                 confirmed  deaths
# country
# Afghanistan                       70111.0  2899.0
# Albania                          132297.0  2449.0
# Algeria                          128456.0  3460.0
# Andorra                           13693.0   127.0
# Angola                            34180.0   757.0
# ...                                   ...     ...
# West Bank and Gaza               307838.0  3492.0
# Yemen                              6731.0  1319.0
# Zambia                            94751.0  1276.0
# Zimbabwe                          38933.0  1594.0
# occupied Palestinian territory        0.0     0.0
#
# [221 rows x 2 columns]
# <AxesSubplot:xlabel='country'>

# %%
Основные параметры метода plot()

x — название признака, который будет отложен по оси абсцисс;
y — название признака, который будет отложен по оси ординат;
figsize — размер графика (кортеж из ширины и высоты в дюймах);
kind —тип визуализации. Основные типы:
'line' — линейный график (по умолчанию);
'bar' — столбчатая диаграмма;
'barh' — горизонтальная столбчатая диаграмма;
'hist' — гистограмма;
'box' — коробчатая диаграмма (boxplot);
'pie' — круговая диаграмма;
'scatter' — диаграмма рассеяния.
grid — отображение сетки (по умолчанию False);
legend — отображение легенды (по умолчанию False);
title — название графика;
color — цвет.

# %%
covid_df.groupby(['country'])['total_vaccinations'].last().nsmallest(5).plot(kind='bar');

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (8, 4))
ax = fig.add_axes([0,0,1,1])

# %%
import matplotlib.pyplot as plt
us_data = covid_df
